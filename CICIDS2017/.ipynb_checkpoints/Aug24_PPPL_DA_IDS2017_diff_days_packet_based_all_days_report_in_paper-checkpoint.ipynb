# %%
import tensorflow as tf
import numpy as np
# %load_ext autoreload
# %autoreload 2
import os
import sys
import time
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras import Model
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'
from sklearn import metrics
import sklearn

# %%
class DataHandler():
    def __init__(self,dataset,labels,weights,batch_size = 64,shuffle=False):
        self.dataset = dataset
        self.current = 0
        self.len = len(dataset)
        self.batch_size = batch_size
        self.labels = labels
        self.do_shuffle = shuffle
        self.inds = np.arange(self.len)
        self.weights = weights
        assert self.len>=batch_size
        assert len(labels)==len(dataset)
        if self.do_shuffle:
            self.shuffle()
    def shuffle(self):
        if self.do_shuffle:
            p = np.random.permutation(len(self.dataset))
            self.inds = p
    def next_batch(self,batch_size = None):
        if batch_size is None:
            batch_size = self.batch_size
        current_inds = self.inds[self.current:self.current+batch_size]
        batch = self.dataset[current_inds]
        y_batch = self.labels[current_inds]
        if self.weights is not None:
            w_batch = self.weights[current_inds]
        self.current +=batch_size
        if self.current>=self.len:
            new_inds = self.inds[:batch_size-len(batch)]
#             batch = torch.cat((batch,self.dataset[new_inds]))
            batch = np.concatenate((batch,self.dataset[new_inds]))
#             y_batch = torch.cat((y_batch,self.labels[new_inds]))
            y_batch = np.concatenate((y_batch,self.labels[new_inds]))
            if self.weights is not None:
#                 w_batch =  torch.cat((w_batch,self.weights[new_inds]))
                w_batch =  np.concatenate((w_batch,self.weights[new_inds]))
            self.current=0
            self.shuffle()
        if self.weights is not None:
            return batch,y_batch,w_batch
        return batch,y_batch

# %%
class PacketModel(Model):
    def __init__(self):
        super(PacketModel, self).__init__()
        self.flatten = Flatten()
        self.d1 = Dense(2048, activation='relu')
        self.d2 = Dense(2)

    def call(self, x):
        x = self.flatten(x)
        dense1_out = self.d1(x)
        dense2_out = self.d2(dense1_out)
        return dense2_out

# %%
def adjust_learning_rate_inv(lr, optimizer, iters, alpha=0.001, beta=0.75):
    lr = lr / pow(1.0 + alpha * iters, beta)
    optimizer.lr.assign(lr)

# %%
class Solver():
    def __init__(self,optimizer,net,base_lr):
        self.iters = 0
        self.optimizer = optimizer
        self.net = net
        self.base_lr = base_lr
    def update_lr(self):
        adjust_learning_rate_inv(self.base_lr,self.optimizer,self.iters)

# %%
def get_files(day,prefix = '../../../anomaly_datasets/IDS2017/packet_based/'):
    all_files = []
    prefix = prefix+day
    for file in os.listdir(prefix):
        if file.endswith(".npy") and file.startswith('part'):
            all_files.append(os.path.join(prefix, file))
    all_files = sorted(all_files)
    return all_files

# %%
def preproces_datasets(src_day,trg_day):
    src_files = [
        src_day,
    ]
    trg_files = [
       trg_day,
    ]
    def get_ds(day):
        all_files = get_files(day)
        x_test = []
        for f in all_files:
            print (f)
            x_test.append(np.load(f))
        x_test = np.concatenate(x_test,axis=0)
#         x_test = (x_test - train_min)/(train_max - train_min+0.000001)
        a = timesteps -  len(x_test) % timesteps
        temp = x_test[:a]
        x_test = np.concatenate((x_test,temp),axis=0)
        x_test = x_test.reshape(-1,timesteps*num_input)
        x_test = x_test.astype(np.float32)
        if day.find('monday')>=0:
            y_test = np.zeros(len(x_test),dtype=np.float32)
        else:
            yt = np.load('../../../anomaly_datasets/IDS2017/packet_based/'+day+'/labels.npy')
            a = timesteps -  len(yt) % timesteps
            temp = yt[:a]
            y_test = np.concatenate((yt,temp),axis=0)
            y_test = y_test.reshape(-1,timesteps)
            y_test = y_test[:,-1]
        return x_test,y_test
    x_src = []
    y_src = []
    for day in src_files:
        t1,t2 = get_ds(day)
        x_src.append(t1)
        y_src.append(t2)
    x_src = np.concatenate(x_src)
    y_src = np.concatenate(y_src)

    x_trg = []
    y_trg = []
    for day in trg_files:
        t1,t2 = get_ds(day)
        x_trg.append(t1)
        y_trg.append(t2)
    x_trg = np.concatenate(x_trg)
    y_trg = np.concatenate(y_trg)
    
    print(x_src.shape,y_src.shape,x_trg.shape,y_trg.shape)
    
    x_all = np.concatenate((x_src,x_trg),axis=0)
#     x_all = x_src
    
    train_min = np.min(x_all,axis=0)
    train_max = np.max(x_all,axis=0)
    # train_min = np.min(x_train,axis=0)
    # train_max = np.max(x_train,axis=0)

    x_src  = (x_src - train_min)/(train_max - train_min + 1e-6)
    x_trg  = (x_trg - train_min)/(train_max - train_min + 1e-6)

    
#     print('mal rate in x_test2',np.sum(y_test2==1)/len(y_test2))
    
    return x_src,y_src,x_trg,y_trg,train_min,train_max

# %%
@tf.function
def train_step(x, y, optimizer,net):
    with tf.GradientTape() as tape:
        y_pred = net(x, training=True)
        mse_loss = tf.reduce_sum((y - y_pred)**2,axis=1)
        mse_loss = tf.reduce_mean(mse_loss)
    gradients = tape.gradient(mse_loss, net.trainable_variables)
    optimizer.apply_gradients(zip(gradients, net.trainable_variables))
    train_loss(mse_loss)

# %%
def train_model2(nb_iters,dhandler,tsolver):
    st = time.time()
    train_loss.reset_states()
    for i in range(nb_iters):
        x_batch,y_batch = dhandler.next_batch()

        if i%5==0:
            tsolver.iters+=1
            tsolver.update_lr()

        train_step(x_batch,y_batch,tsolver.optimizer,tsolver.net)
        if i % 50 == 49 or i == nb_iters - 1:
            remained_iters = nb_iters - i
            passed_time = time.time() - st
            ETA = int(passed_time * remained_iters / i)
            ETA_min, ETA_sec = ETA // 60, ETA % 60
            mean_loss = train_loss.result().numpy()
            print ('\r' + \
                  ' iter: ' + str(i + 1) + '/' + str(nb_iters) + \
                  ' ETA: ' + str(ETA_min) + ':' + "{0:02d}".format(ETA_sec) + \
                  ' loss: ' + "{0:0.4f}".format(mean_loss),end=" ")
            sys.stdout.flush()
    print(' ')

# %%
@tf.function
def test_step(x,net):
    return net(x,training=False)

# %%
def test(x_ds,y_ds,net,ret=False):
    all_y_pred = np.zeros_like(y_ds)
    all_scores = np.zeros((len(y_ds),2))
    for i in range(0,len(x_ds),batch_size):
        x_batch = x_ds[i:i+batch_size]
        y_batch = y_ds[i:i+batch_size]
        y_pred = test_step(x_batch,net)
        y_pred = y_pred.numpy()
        all_scores[i:i+batch_size] = y_pred
        y_pred = y_pred.argmax(axis=1)
    #             return np.sum(Preds==Labels)/len(Preds)
        all_y_pred[i:i+batch_size] = y_pred
    print('accuracy:',np.sum(all_y_pred==y_ds)/len(y_ds))
    if ret:
        return all_y_pred,all_scores

# %%
def calc_scores(x_ds,y_ds,net,draw=True):
    all_y_pred,probs_np = test(x_ds,y_ds,net,ret=True)
    gt_labels = y_ds
    acc = sklearn.metrics.accuracy_score(y_true=gt_labels,y_pred=probs_np.argmax(axis=1))
    print('accuracy:',acc)
    f1 = sklearn.metrics.f1_score(y_true=gt_labels,y_pred=probs_np.argmax(axis=1))
    print('f1 score:',f1)

    precision, recall, thresholds = sklearn.metrics.precision_recall_curve(y_true=gt_labels,probas_pred=probs_np[:,1],pos_label=1)
    auprc = sklearn.metrics.auc(recall,precision)
    print('AUPRC:',auprc)
    
    
    if draw:
        print('balanced accuracy:',sklearn.metrics.balanced_accuracy_score(y_true=gt_labels,y_pred=probs_np.argmax(axis=1)))
        print('precision:',sklearn.metrics.precision_score(y_true=gt_labels,y_pred=probs_np.argmax(axis=1)))
        print('recall:',sklearn.metrics.recall_score(y_true=gt_labels,y_pred=probs_np.argmax(axis=1)))

        
        plt.figure(figsize=(15,10))
        plt.subplot(2,2,1)
        plt.step(recall, precision, color='b', alpha=0.2, where='post')
        plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        
        fpr,tpr,thr = sklearn.metrics.roc_curve(y_true=gt_labels,y_score=probs_np[:,1])
        print('ROC-AUC',sklearn.metrics.auc(fpr,tpr))
        
        plt.subplot(2,2,2)
        plt.step(fpr, tpr, color='b', alpha=0.2, where='post')
        plt.fill_between(fpr, tpr, step='post', alpha=0.2, color='b')
        plt.xlabel('FPR')
        plt.ylabel('TPR')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.0])
        return precision,recall,fpr,tpr
    return f1,auprc,acc


def calc_f1_score(x_ds,y_ds):
    all_y_pred,probs_np = test(x_ds,y_ds,net,ret=True)
    f1_score = metrics.f1_score(y_true=y_ds,y_pred=all_y_pred)
    print('f1 score:',f1_score)
    return f1_score

# %% [markdown]
# # train_model

# %%
@tf.function
def train_step_DA(x, y, w, optimizer,net):
    with tf.GradientTape() as tape:
        y_pred = net(x, training=True)
        mse_loss = tf.reduce_sum((y - y_pred)**2,axis=1)*w
        mse_loss = tf.reduce_mean(mse_loss)
    gradients = tape.gradient(mse_loss, net.trainable_variables)
    optimizer.apply_gradients(zip(gradients, net.trainable_variables))
    train_loss(mse_loss)

# %%
def train_model(nb_epochs,dhandler,tsolver):
    total_batch = dhandler.len // dhandler.batch_size
    if dhandler.len % dhandler.batch_size != 0:
        total_batch += 1
    st = time.time()
    for ep in range(nb_epochs):
        train_loss.reset_states()
        for i in range(total_batch):
            x_batch,y_batch_t,w_batch = dhandler.next_batch()
            y_batch = np.zeros((dhandler.batch_size,2),dtype=np.float32)
            y_batch[range(dhandler.batch_size),y_batch_t] = 1
#             if i%5==0:
#                 tsolver.iters+=1
#                 tsolver.update_lr()
            train_step_DA(x_batch,y_batch,w_batch,tsolver.optimizer,tsolver.net)
#             train_step(x_batch,y_batch,tsolver.optimizer,tsolver.net)


            # update the network
        passed_time = time.time() - st
        remained_epochs = nb_epochs - ep
        ETA = int(passed_time * remained_epochs)
        ETA_min, ETA_sec = ETA // 60, ETA % 60
        print ('\r' + 'epoch: ' + str(ep + 1) + '/' + str(nb_epochs) + \
                      ' ETA: ' + str(ETA_min) + ':' + "{0:02d}".format(ETA_sec) + \
                      ' loss: ' + "{0:0.4f}".format(train_loss.result().numpy()),end=" ")
        sys.stdout.flush()
    print(' ')

# %%
# def recalc_labels(trg_probs_np,trg_gt_class_percentage):
#     n_classes = 2
#     labels_w_class_rates = trg_probs_np.argmax(axis=1)
#     current_class_percentage = np.zeros(n_classes)
#     for i2 in range(n_classes):
#         current_class_percentage[i2] = np.sum(labels_w_class_rates==i2)/len(trg_probs_np)

#     diff_class_rates =  current_class_percentage - trg_gt_class_percentage
#     for i in range(len(diff_class_rates)):
#         if diff_class_rates[i]<=0:
#             continue
#         predicted_as_c = labels_w_class_rates==i
#         current_class = i
#         current_diff = diff_class_rates[i]
#         current_num = np.round(current_diff*len(trg_probs_np)).astype(np.int32)

#         current_probs = trg_probs_np[labels_w_class_rates==current_class]
#         avg_score_sorted = np.sort(current_probs,axis=1)
#         diff_probs = avg_score_sorted[:,-1] - avg_score_sorted[:,-2]
        
#         diff_probs_sorted_inds = np.argsort(diff_probs)
#         y_val = np.ones(len(diff_probs))*current_class
#         for i in range(current_num):
#             y_val[i]=-1
#         weights_trg2 = np.zeros(len(diff_probs))
#         weights_trg2[diff_probs_sorted_inds] = y_val
#         labels_w_class_rates[predicted_as_c] = weights_trg2
    
#     return labels_w_class_rates,trg_probs_np

# %%
# trg_probs_np = af.calculate_with_small_batch([my_model.probs],[last_fixed_layer],[global_pool_trg],sess,batch_size=128)
def recalc_labels(trg_probs_np,trg_gt_class_percentage):

#     diff_class_rates =  trg_gt_class_percentage - current_class_percentage
    # print(diff_class_rates*len(trg_probs_np))
#     sorted_ind_class_rates = np.argsort(diff_class_rates)
    
    visited = []
    labels_w_class_rates = trg_probs_np.argmax(axis=1)
    for i in range(n_classes):

        current_class_percentage = np.zeros(n_classes)
        for i2 in range(n_classes):
#             current_class_percentage[i2] = np.sum(trg_probs_np.argmax(axis=1)==i2)/len(trg_probs_np)
            current_class_percentage[i2] = np.sum(labels_w_class_rates==i2)/len(trg_probs_np)

        diff_class_rates =  trg_gt_class_percentage - current_class_percentage
        
#         print(diff_class_rates*len(trg_probs_np))
    #     sorted_ind_class_rates = np.argsort(diff_class_rates)
    #     current_class = sorted_ind_class_rates[i]
        current_class = np.argmin(diff_class_rates)
        current_diff = -1*diff_class_rates[current_class]
        current_num = np.round(current_diff*len(trg_probs_np)).astype(np.int32)
#         print(current_num,current_class)
        visited.append(current_class)
        if current_num <= 0:
            continue
        ### take the samples which are predicted as current_class
#         current_probs = trg_probs_np[trg_probs_np.argmax(axis=1)==current_class]
        current_probs = trg_probs_np[labels_w_class_rates==current_class]
#         print(current_probs.shape)
        current_probs_sorted = np.argsort(current_probs.max(axis=1))
        ### need to change their labels:
        tobe_changed_indx = current_probs_sorted[:current_num]
        tobe_changed_current_probs = current_probs[tobe_changed_indx]
        #### sorted value of probs
        as_probs = np.argsort(tobe_changed_current_probs)

        o2 = as_probs
        cond = np.ones_like(o2).astype(np.bool)
        for e in visited:
        #     o2 = o2[o2!=e]
            cond = cond & (o2!=e)
    #         print(cond.shape)
        o2 = o2[cond]
        if len(o2)==0:
            continue
        o2 = o2.reshape(len(as_probs),-1)
    #     print (o2.shape)
        new_labels = o2[:,-1]
        res = np.ones(len(current_probs))*current_class
        temp = tobe_changed_current_probs[range(len(tobe_changed_current_probs)),current_class]
        tobe_changed_current_probs[range(len(tobe_changed_current_probs)),current_class]=tobe_changed_current_probs[range(len(tobe_changed_current_probs)),new_labels]
        tobe_changed_current_probs[range(len(tobe_changed_current_probs)),new_labels]=temp
#         tobe_changed_current_probs[range(len(tobe_changed_current_probs)),current_class]=0
#         tobe_changed_current_probs[range(len(tobe_changed_current_probs)),new_labels]+=temp

    #     print(res.shape)
        res[tobe_changed_indx] = new_labels
        current_probs[tobe_changed_indx] = tobe_changed_current_probs
#         print(current_probs.shape,res.shape)
        trg_probs_np[labels_w_class_rates==current_class] = current_probs
        labels_w_class_rates[labels_w_class_rates==current_class] = res

    #     print(labels_w_class_rates[50],'rrrrr')
    #     print(res)
    #     print(np.sort(tobe_changed_indx))
    #     if i==80:
    #         break
    return labels_w_class_rates,trg_probs_np

# %%
#### for some iterations:
def DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage,st_nnn = 0,mode=1):
#     tsolver.net.eval()
    begin_time = time.time()
    my_coef = 0.05
#     for nnn in range(0,90,2):
    for nnn in range(st_nnn,90,2):
        print('#########################################',nnn)
        inner_loop = 1
        if nnn>=88:
            inner_loop=1
        for jjj in range(inner_loop):
            print ('^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch:',jjj,
               'Elapsed Time(m): {0:0.2f}'.format((time.time()-begin_time)/60))
#             weights_src3 = torch.ones(len(src_gts))
            weights_src3 = np.ones(len(src_gts))

            y_pred_trg,logits_trg = test(trg_data,trg_gts,net,ret=True)
            big_avg_score = logits_trg
            avg_pred_labels = big_avg_score.argmax(axis=1)
            
            if mode==2:
                if nnn<60:
                    #do something
                    for i in range(2):
                        temp = np.sum(avg_pred_labels==i)/len(avg_pred_labels)
                        trg_gt_class_percentage[i] = 0.7*trg_gt_class_percentage[i] + 0.3*temp
    #                 trg_gt_class_percentage[i] = temp
    #             else:
    #             trg_gt_class_percentage_current = 0.9*trg_gt_class_percentage_current + 0.1*trg_gt_class_percentage
                
            print('%%%%%%%',np.sum(np.abs(trg_gt_class_percentage - trg_gt_class_percentage0)))
            
            avg_pred_labels2, big_avg_score2 = recalc_labels(np.copy(big_avg_score),trg_gt_class_percentage)
#             big_avg_score = big_avg_score2
            
            
        
            if nnn<60:
                big_avg_score = big_avg_score2
                avg_pred_labels = avg_pred_labels2

            
            
    #         y_trg = trg_gts.cpu()
#             y_trg = trg_labels.cpu()
            y_trg = trg_gts

            avg_score_sorted = np.sort(big_avg_score,axis=1)
            diff_probs = avg_score_sorted[:,-1] - avg_score_sorted[:,-2]


#             weights_trg3 = np.ones(len(diff_probs))
            
            weights_trg3 = np.zeros(len(diff_probs))
            for c in range(n_classes):
                predicted_as_c = avg_pred_labels==c
                size_c = np.sum(predicted_as_c)
                if size_c>1:
    #                 print(c,size_c,end=' ')
    #                 if nnn<=15:
                    left_size = int(np.ceil(((nnn+1)*0.01+0.1)*size_c))
                    x_val_left = 1+(10/2 - 1)/left_size*(np.arange(left_size))
                    right_size = size_c - left_size
    #                 x_val_right = 5 + (size_c - 5)/right_size*(np.arange(0,right_size))
                    x_val_right = 10000*(np.arange(1,right_size+1))
                    x_val = np.concatenate((x_val_left,x_val_right))
                    y_val = np.power(x_val,-1)
                    y_val = y_val[::-1]
    #                 x_val = np.arange(size_c)*1+1 + my_coef*nnn
    #                 y_val = np.power(x_val,-.99)
    #                 y_val = (y_val - y_val.min())/(y_val.max() - y_val.min())
    #                 y_val = y_val[::-1]

                    diff_c = diff_probs[predicted_as_c]
                    diff_probs_sorted_inds_c = np.argsort(diff_c)
                    weights_trg2 = np.zeros(len(diff_c))
                    weights_trg2[diff_probs_sorted_inds_c] = y_val
                    weights_trg3[predicted_as_c] = weights_trg2

            coef = (avg_pred_labels==avg_pred_labels2)*1
            weights_trg3*=coef
            weights_trg3 = weights_trg3.astype(np.float32)
#             plt.scatter(np.arange(len(weights_trg3)),np.sort(weights_trg3))
#             weights_trg3 = torch.tensor(weights_trg3)


            #     big_cond = (diff_probs>=thr)
#             big_cond = np.zeros(len(big_avg_score))==0
            big_cond = weights_trg3>=0.001
            print('len of big_cond',np.sum(big_cond),'len of trg weights',len(weights_trg3))
#             correct_indices = avg_pred_labels == y_trg.numpy()
            correct_indices = avg_pred_labels == y_trg
            mal_inds = y_trg==1    
            print('len of correcT_indices',np.sum(correct_indices),'correct mals:',np.sum(correct_indices&mal_inds))
            
            

            new_ratio = np.sum(~correct_indices&big_cond)/np.sum(big_cond)
            #         new_ratio = (len(big_cond) - len(correct_indices)) / len(big_cond)
            #         print(new_ratio*100,np.sum(big_cond),thr)
            print(">>>>>>>>>>>>>>>>>>>>>>>>>>{0:0.4f}".format(new_ratio*100),'iter:',jjj,'elapssed time:',time.time() - begin_time)

#             big_cond = np.argwhere(big_cond)
#             big_cond = big_cond.reshape(-1)
#             correct_indices = np.argwhere(correct_indices)
#             correct_indices = correct_indices.reshape(-1)
            
            correct_x_trg = trg_data[big_cond]
            correct_pseudo_labels = avg_pred_labels[big_cond].astype(np.int32)
            weights_trg3 = weights_trg3[big_cond]

        
#             correct_x_trg = trg_data[big_cond&correct_indices]
#             correct_pseudo_labels = avg_pred_labels[big_cond&correct_indices].astype(np.int32)
#             weights_trg3 = weights_trg3[big_cond&correct_indices]

#             correct_pseudo_labels = torch.tensor(correct_pseudo_labels,dtype=torch.long)

            p = np.random.permutation(len(src_data))
            p = p[:len(trg_data)]
            x_temp = src_data[p]
            y_temp = src_gts[p]
            w_temp = weights_src3[:len(trg_data)]

            m1 = np.concatenate((x_temp,correct_x_trg))
            m2 = np.concatenate((y_temp,correct_pseudo_labels)).astype(np.int32)
            m3 = np.concatenate((w_temp,weights_trg3)).astype(np.float32)
            
                                        
            if nnn<60:
                pos_inds = m2==1
                x_train_pos = m1[pos_inds]
                y_train_pos = m2[pos_inds]
                w_train_pos = m3[pos_inds]
                x_train_neg = m1[~pos_inds]
                y_train_neg = m2[~pos_inds]
                w_train_neg = m3[~pos_inds]
                p = np.random.permutation(len(x_train_neg))
                x_train_neg = x_train_neg[p]
                y_train_neg = y_train_neg[p]
                w_train_neg = w_train_neg[p]
                pos_len = len(x_train_pos)

                correct_dhandler = DataHandler(np.concatenate((x_train_pos,x_train_neg[:pos_len]))
                                                   ,np.concatenate((y_train_pos,y_train_neg[:pos_len]))
                                              ,np.concatenate((w_train_pos,w_train_neg[:pos_len])),batch_size=256,shuffle=True)

            else:
                correct_dhandler = DataHandler(m1, m2, m3, 256,shuffle=True)                


            
            
            print(m1.shape,m2.shape,m3.shape)

            print('------------',correct_dhandler.len)
    #         correct_dhandler_src = DataHandler(x_temp, y_temp, w_temp, 32,shuffle=True)
    #         correct_dhandler_trg = DataHandler(trg_data, correct_pseudo_labels, weights_trg3, 32,shuffle=True)
    #         ep = 2 if nnn == 0 else 3
            ep = 1
            train_model(ep,correct_dhandler,tsolver)

            if nnn%8==0:
    #             train_solver.net.module.set_bn_domain(train_solver.bn_domain_map[train_solver.target_name])
#                 with torch.no_grad():
                print('current accuracy on target domain: ',end=' ')
                test(trg_data,trg_gts,net)
#                 print('current accuracy on target domain: ',current_acc)
#             else:
#                 net.eval()

# %%
timesteps = 20
num_input = 29
label_names = ['Benign','FTP-Patator','SSH-Patator','Slowloris','Slowhttptest','Hulk','GoldenEye','Heartbleed', 
               'Web-Attack', 'Infiltration','Botnet','PortScan','DDoS']

# %%
days = ['tuesday','wednesday','thursday']

# %%
# onlysrc_res = {}
# pppl_res = {}
# for src_day in days:
#     for trg_day in days:
#         if src_day==trg_day:
#             continue
#         print('**************************************************',src_day,trg_day)
#         x_src,y_src,x_trg,y_trg,train_min,train_max = preproces_datasets(src_day,trg_day)
#         real_labels = y_src!=-1
#         x_src = x_src[real_labels]
#         y_src = y_src[real_labels]

#         real_labels = y_trg!=-1
#         x_trg = x_trg[real_labels]
#         y_trg = y_trg[real_labels]

#         print(x_src.shape,y_src.shape,x_trg.shape,y_trg.shape)
        
#         y_src[y_src!=0] = 1
#         y_trg[y_trg!=0] = 1
        
#         print('mal rate in src',np.sum(y_src==1)/len(y_src))
#         print('mal rate in trg',np.sum(y_trg==1)/len(y_trg))
        
#         y_src_onehot = np.zeros((len(y_src),2),np.float32)
#         y_src_onehot[range(len(y_src)),y_src.astype(np.int32)] = 1.

#         y_trg_onehot = np.zeros((len(y_trg),2),np.float32)
#         y_trg_onehot[range(len(y_trg)),y_trg.astype(np.int32)] = 1.
        
#         input_size = x_src.shape[1]
#         net = PacketModel()
#         net._set_inputs(tf.TensorSpec([None,timesteps*num_input]))
        
        
#         base_lr = 0.0001
#         optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
#         grads = []
#         for v in net.trainable_variables:
#             grads.append(np.zeros(v.shape))
#         optimizer.apply_gradients(zip(grads,net.trainable_variables))

#         tsolver = Solver(optimizer,net,base_lr)
#         train_loss = tf.keras.metrics.Mean(name='train_loss')
        
        
#         nb_epochs = 6
#         batch_size = 256
#         total_batch = len(x_src)//batch_size
#         if len(x_src) % batch_size!=0:
#             total_batch+=1
#         RANDOM_SEED = 2020
#         rng = np.random.RandomState(RANDOM_SEED)
        
        
#         for i in range(nb_epochs):
#             pos_inds = y_src==1
#             x_src_pos = x_src[pos_inds]
#             y_src_pos = y_src_onehot[pos_inds]
#             x_src_neg = x_src[~pos_inds]
#             y_src_neg = y_src_onehot[~pos_inds]
#             p = np.random.permutation(len(x_src_neg))
#             x_src_neg = x_src_neg[p]
#             y_src_neg = y_src_neg[p]
#             pos_len = len(x_src_pos)

#             src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
#                                                ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

#             train_model2(total_batch,src_dhandler,tsolver)
            
#         name = src_day[:2]+'_'+trg_day[:2]
#         net.save('../../../saved_models/IDS/'+name+'_only_src')
        
#         x_trg = x_trg[::2]
#         y_trg = y_trg[::2]
        
        
        
        
#         f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
#         onlysrc_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
#         y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
#         for fpr in [0.001,0.01,0.1]:
#             scores = scores_trg[:,1]
#         #     fpr = 0.01
#             benign_scores = scores[y_trg==0]
#             benign_scores_sorted = np.sort(benign_scores)
#             thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
#             thr = benign_scores_sorted[-thr_ind]
#             print (thr)
#             mal_scores = scores[y_trg==1]
#             tpr = np.sum(mal_scores>thr)/len(mal_scores)
#             print('TPR:',tpr)
#             onlysrc_res[name].append((fpr,tpr))
            
            
        
        
#         ########################### DA
#         base_lr = 0.0001
#         # optimizer = torch.optim.Adam(net.parameters(),lr=base_lr)
#         optimizer = tf.keras.optimizers.Adam(lr=base_lr)
#         grads = []
#         for v in net.trainable_variables:
#             grads.append(np.zeros(v.shape))
#         optimizer.apply_gradients(zip(grads,net.trainable_variables))

#         tsolver = Solver(optimizer,net,base_lr)

#         # trg_preds = get_logits(x_target,y_target,tsolver)
#         trg_gts = y_trg
#         trg_data = x_trg
#         src_gts = y_src
#         src_data = x_src
#         t_labels = np.array(trg_gts)
#         l_trg = t_labels
#         trg_size = len(trg_data)
#         n_classes = 2
#         trg_gt_class_percentage = np.zeros(n_classes)
#         for i in range(n_classes):
#             trg_gt_class_percentage[i] = np.sum(t_labels==i)/len(t_labels)
        
#         DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage)
        
#         net.save('../../saved_models/IDS/'+name+'_pppl')
        
#         f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
#         pppl_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
#         y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
#         for fpr in [0.001,0.01,0.1]:
#             scores = scores_trg[:,1]
#         #     fpr = 0.01
#             benign_scores = scores[y_trg==0]
#             benign_scores_sorted = np.sort(benign_scores)
#             thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
#             thr = benign_scores_sorted[-thr_ind]
#             print (thr)
#             mal_scores = scores[y_trg==1]
#             tpr = np.sum(mal_scores>thr)/len(mal_scores)
#             print('TPR:',tpr)
#             pppl_res[name].append((fpr,tpr))
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')
#         print(onlysrc_res)
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')
#         print(pppl_res)
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')

# %%
# print('name','f1_only_src','f1_pppl','fpr0.01_only_src','fpr0.01_pppl')
# for src_day in days:
#     for trg_day in days:
#         if src_day == trg_day:
#             continue
#         name = src_day[:2]+'_'+trg_day[:2]
#         print(name,onlysrc_res[name][0][1],pppl_res[name][0][1],onlysrc_res[name][4][1],pppl_res[name][4][1])

# %%
import pickle

# %%
# with open('onlysrc_res','wb') as f:
#     pickle.dump(onlysrc_res,f)
    
# with open('pppl_res','wb') as f:
#     pickle.dump(pppl_res,f)

# %%
# def print_res(ht=None):
#     for src_day in days:
#         for trg_day in days:
#             if src_day == trg_day:
#                 continue
#             name = src_day[:2]+'_'+trg_day[:2]
#             if ht is None:
#                 print(name,end=' ')
#             else:
# #                 temp = ht[name][0][1] #f1 score
#                 temp = ht[name][4][1] #f1 score
#                 print(temp,end=' ')
#     print()
# print_res()
# print_res(onlysrc_res)
# print_res(pppl_res)

# %% [markdown]
# # Params like other DS

# %%
days = ['tuesday','wednesday','thursday']

# %%
# onlysrc_res = {}
# pppl_res = {}
# for src_day in days:
#     for trg_day in days:
# # for src_day in ['tuesday']:
# #     for trg_day in ['thursday']:
#         if src_day==trg_day:
#             continue
#         print('**************************************************',src_day,trg_day)
#         x_src,y_src,x_trg,y_trg,train_min,train_max = preproces_datasets(src_day,trg_day)
#         real_labels = y_src!=-1
#         x_src = x_src[real_labels]
#         y_src = y_src[real_labels]

#         real_labels = y_trg!=-1
#         x_trg = x_trg[real_labels]
#         y_trg = y_trg[real_labels]

#         print(x_src.shape,y_src.shape,x_trg.shape,y_trg.shape)
        
#         y_src[y_src!=0] = 1
#         y_trg[y_trg!=0] = 1
        
#         x_src = x_src[::2]
#         y_src = y_src[::2]
        
#         x_trg = x_trg[::2]
#         y_trg = y_trg[::2]
        
#         print('mal rate in src',np.sum(y_src==1)/len(y_src))
#         print('mal rate in trg',np.sum(y_trg==1)/len(y_trg))
        
#         y_src_onehot = np.zeros((len(y_src),2),np.float32)
#         y_src_onehot[range(len(y_src)),y_src.astype(np.int32)] = 1.

#         y_trg_onehot = np.zeros((len(y_trg),2),np.float32)
#         y_trg_onehot[range(len(y_trg)),y_trg.astype(np.int32)] = 1.
        
#         input_size = x_src.shape[1]
#         net = PacketModel()
#         net._set_inputs(tf.TensorSpec([None,timesteps*num_input]))
        
        
#         base_lr = 0.0001
#         optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
#         grads = []
#         for v in net.trainable_variables:
#             grads.append(np.zeros(v.shape))
#         optimizer.apply_gradients(zip(grads,net.trainable_variables))

#         tsolver = Solver(optimizer,net,base_lr)
#         train_loss = tf.keras.metrics.Mean(name='train_loss')
        
        
#         nb_epochs = 6
#         batch_size = 256
#         total_batch = len(x_src)//batch_size
#         if len(x_src) % batch_size!=0:
#             total_batch+=1
#         RANDOM_SEED = 2020
#         rng = np.random.RandomState(RANDOM_SEED)
# #         src_dhandler = DataHandler(x_src,y_src_onehot,None,batch_size=256,shuffle=True)
        
#         for i in range(nb_epochs):
#             pos_inds = y_src==1
#             x_src_pos = x_src[pos_inds]
#             y_src_pos = y_src_onehot[pos_inds]
#             x_src_neg = x_src[~pos_inds]
#             y_src_neg = y_src_onehot[~pos_inds]
#             p = np.random.permutation(len(x_src_neg))
#             x_src_neg = x_src_neg[p]
#             y_src_neg = y_src_neg[p]
#             pos_len = len(x_src_pos)

#             src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
#                                                ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

#             train_model2(total_batch,src_dhandler,tsolver)
            
#         name = src_day[:2]+'_'+trg_day[:2]
#         net.save('../../saved_models/IDS/'+name+'_only_src3')
        

        
        
        
#         f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
#         onlysrc_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
#         y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
#         for fpr in [0.001,0.01,0.1]:
#             scores = scores_trg[:,1]
#         #     fpr = 0.01
#             benign_scores = scores[y_trg==0]
#             benign_scores_sorted = np.sort(benign_scores)
#             thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
#             thr = benign_scores_sorted[-thr_ind]
#             print (thr)
#             mal_scores = scores[y_trg==1]
#             tpr = np.sum(mal_scores>thr)/len(mal_scores)
#             print('TPR:',tpr)
#             onlysrc_res[name].append((fpr,tpr))
            
            
        
        
#         ########################### DA
#         base_lr = 0.0001
#         # optimizer = torch.optim.Adam(net.parameters(),lr=base_lr)
#         optimizer = tf.keras.optimizers.Adam(lr=base_lr)
#         grads = []
#         for v in net.trainable_variables:
#             grads.append(np.zeros(v.shape))
#         optimizer.apply_gradients(zip(grads,net.trainable_variables))

#         tsolver = Solver(optimizer,net,base_lr)

#         # trg_preds = get_logits(x_target,y_target,tsolver)
#         trg_gts = y_trg
#         trg_data = x_trg
#         src_gts = y_src
#         src_data = x_src
#         t_labels = np.array(trg_gts)
#         l_trg = t_labels
#         trg_size = len(trg_data)
#         n_classes = 2
#         trg_gt_class_percentage = np.zeros(n_classes)
#         for i in range(n_classes):
#             trg_gt_class_percentage[i] = np.sum(t_labels==i)/len(t_labels)
        
#         DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage)
        
#         net.save('../../saved_models/IDS/'+name+'_pppl3')
        
#         f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
#         pppl_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
#         y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
#         for fpr in [0.001,0.01,0.1]:
#             scores = scores_trg[:,1]
#         #     fpr = 0.01
#             benign_scores = scores[y_trg==0]
#             benign_scores_sorted = np.sort(benign_scores)
#             thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
#             thr = benign_scores_sorted[-thr_ind]
#             print (thr)
#             mal_scores = scores[y_trg==1]
#             tpr = np.sum(mal_scores>thr)/len(mal_scores)
#             print('TPR:',tpr)
#             pppl_res[name].append((fpr,tpr))
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')
#         print(onlysrc_res)
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')
#         print(pppl_res)
#         print('--------------------------------------------------------------------------------------------')
#         print('--------------------------------------------------------------------------------------------')

# %%
onlysrc_res = {}
pppl_res = {}
# for src_day in days:
#     for trg_day in days:
for src_day in ['thursday']:
    for trg_day in ['tuesday']:
        if src_day==trg_day:
            continue
        print('**************************************************',src_day,trg_day)
        x_src,y_src,x_trg,y_trg,train_min,train_max = preproces_datasets(src_day,trg_day)


        print(x_src.shape,y_src.shape,x_trg.shape,y_trg.shape)
        
        y_src[y_src!=0] = 1
        y_trg[y_trg!=0] = 1
        
        print('mal rate in src',np.sum(y_src==1)/len(y_src))
        print('mal rate in trg',np.sum(y_trg==1)/len(y_trg))
        
        y_src_onehot = np.zeros((len(y_src),2),np.float32)
        y_src_onehot[range(len(y_src)),y_src.astype(np.int32)] = 1.

        y_trg_onehot = np.zeros((len(y_trg),2),np.float32)
        y_trg_onehot[range(len(y_trg)),y_trg.astype(np.int32)] = 1.
        
        input_size = x_src.shape[1]
        net = PacketModel()
        net._set_inputs(tf.TensorSpec([None,timesteps*num_input]))
        
        
        base_lr = 0.0001
        optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
        grads = []
        for v in net.trainable_variables:
            grads.append(np.zeros(v.shape))
        optimizer.apply_gradients(zip(grads,net.trainable_variables))

        tsolver = Solver(optimizer,net,base_lr)
        train_loss = tf.keras.metrics.Mean(name='train_loss')
        
        
        nb_epochs = 6
        batch_size = 256
        total_batch = len(x_src)//batch_size
        if len(x_src) % batch_size!=0:
            total_batch+=1
        RANDOM_SEED = 2020
        rng = np.random.RandomState(RANDOM_SEED)
#         src_dhandler = DataHandler(x_src,y_src_onehot,None,batch_size=256,shuffle=True)
        
        for i in range(nb_epochs):
            pos_inds = y_src==1
            x_src_pos = x_src[pos_inds]
            y_src_pos = y_src_onehot[pos_inds]
            x_src_neg = x_src[~pos_inds]
            y_src_neg = y_src_onehot[~pos_inds]
            p = np.random.permutation(len(x_src_neg))
            x_src_neg = x_src_neg[p]
            y_src_neg = y_src_neg[p]
            pos_len = len(x_src_pos)

            src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
                                               ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

            train_model2(total_batch,src_dhandler,tsolver)
            
        name = src_day[:2]+'_'+trg_day[:2]
#         net.save('../../saved_models/IDS/'+name+'_only_src4')
        
        x_trg = x_trg[::2]
        y_trg = y_trg[::2]
        
        
        
        
        f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
        onlysrc_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
        y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
        for fpr in [0.001,0.01,0.1]:
            scores = scores_trg[:,1]
        #     fpr = 0.01
            benign_scores = scores[y_trg==0]
            benign_scores_sorted = np.sort(benign_scores)
            thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
            thr = benign_scores_sorted[-thr_ind]
            print (thr)
            mal_scores = scores[y_trg==1]
            tpr = np.sum(mal_scores>thr)/len(mal_scores)
            print('TPR:',tpr)
            onlysrc_res[name].append((fpr,tpr))
            
            
        
        
        ########################### DA
        base_lr = 0.0001
        # optimizer = torch.optim.Adam(net.parameters(),lr=base_lr)
        optimizer = tf.keras.optimizers.Adam(lr=base_lr)
        grads = []
        for v in net.trainable_variables:
            grads.append(np.zeros(v.shape))
        optimizer.apply_gradients(zip(grads,net.trainable_variables))

        tsolver = Solver(optimizer,net,base_lr)

        # trg_preds = get_logits(x_target,y_target,tsolver)
        trg_gts = y_trg
        trg_data = x_trg
        src_gts = y_src
        src_data = x_src
        t_labels = np.array(trg_gts)
        l_trg = t_labels
        
        s_labels = np.array(src_gts)
        l_src = s_labels
        trg_size = len(trg_data)
        n_classes = 2
        
        trg_gt_class_percentage0 = np.zeros(n_classes)
        for i in range(n_classes):
            trg_gt_class_percentage0[i] = np.sum(t_labels==i)/len(t_labels)
        
        trg_gt_class_percentage = np.zeros(n_classes)
        for i in range(n_classes):
            trg_gt_class_percentage[i] = np.sum(t_labels==i)/len(t_labels)
#             trg_gt_class_percentage[i] = np.sum(s_labels==i)/len(s_labels)
        
        DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage)
        
#         net.save('../../saved_models/IDS/'+name+'_pppl4')
        
        f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
        pppl_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
        y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
        for fpr in [0.001,0.01,0.1]:
            scores = scores_trg[:,1]
        #     fpr = 0.01
            benign_scores = scores[y_trg==0]
            benign_scores_sorted = np.sort(benign_scores)
            thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
            thr = benign_scores_sorted[-thr_ind]
            print (thr)
            mal_scores = scores[y_trg==1]
            tpr = np.sum(mal_scores>thr)/len(mal_scores)
            print('TPR:',tpr)
            pppl_res[name].append((fpr,tpr))
        print('--------------------------------------------------------------------------------------------')
        print('--------------------------------------------------------------------------------------------')
        print(onlysrc_res)
        print('--------------------------------------------------------------------------------------------')
        print('--------------------------------------------------------------------------------------------')
        print(pppl_res)
        print('--------------------------------------------------------------------------------------------')
        print('--------------------------------------------------------------------------------------------')

# %%
onlysrc_res = {}
pppl_res = {}
# for src_day in days:
#     for trg_day in days:
for src_day in ['wednesday']:
    for trg_day in ['tuesday']:
        if src_day==trg_day:
            continue
        print('**************************************************',src_day,trg_day)
        x_src,y_src,x_trg,y_trg,train_min,train_max = preproces_datasets(src_day,trg_day)
        real_labels = y_src!=-1
        x_src = x_src[real_labels]
        y_src = y_src[real_labels]

        real_labels = y_trg!=-1
        x_trg = x_trg[real_labels]
        y_trg = y_trg[real_labels]

        print(x_src.shape,y_src.shape,x_trg.shape,y_trg.shape)
        
        y_src[y_src!=0] = 1
        y_trg[y_trg!=0] = 1
        
        print('mal rate in src',np.sum(y_src==1)/len(y_src))
        print('mal rate in trg',np.sum(y_trg==1)/len(y_trg))
        
        y_src_onehot = np.zeros((len(y_src),2),np.float32)
        y_src_onehot[range(len(y_src)),y_src.astype(np.int32)] = 1.

        y_trg_onehot = np.zeros((len(y_trg),2),np.float32)
        y_trg_onehot[range(len(y_trg)),y_trg.astype(np.int32)] = 1.
        
        input_size = x_src.shape[1]
        net = PacketModel()
        net._set_inputs(tf.TensorSpec([None,timesteps*num_input]))
        
        
        base_lr = 0.0001
        optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
        grads = []
        for v in net.trainable_variables:
            grads.append(np.zeros(v.shape))
        optimizer.apply_gradients(zip(grads,net.trainable_variables))

        tsolver = Solver(optimizer,net,base_lr)
        train_loss = tf.keras.metrics.Mean(name='train_loss')
        
        
        nb_epochs = 6
        batch_size = 256
        total_batch = len(x_src)//batch_size
        if len(x_src) % batch_size!=0:
            total_batch+=1
        RANDOM_SEED = 2020
        rng = np.random.RandomState(RANDOM_SEED)
#         src_dhandler = DataHandler(x_src,y_src_onehot,None,batch_size=256,shuffle=True)
        
        for i in range(nb_epochs):
            pos_inds = y_src==1
            x_src_pos = x_src[pos_inds]
            y_src_pos = y_src_onehot[pos_inds]
            x_src_neg = x_src[~pos_inds]
            y_src_neg = y_src_onehot[~pos_inds]
            p = np.random.permutation(len(x_src_neg))
            x_src_neg = x_src_neg[p]
            y_src_neg = y_src_neg[p]
            pos_len = len(x_src_pos)

            src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
                                               ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

            train_model2(total_batch,src_dhandler,tsolver)
            
        name = src_day[:2]+'_'+trg_day[:2]
        net.save('../../saved_models/IDS/'+name+'_only_src4')
        
        x_trg = x_trg[::2]
        y_trg = y_trg[::2]
        
        net = tf.keras.models.load_model('../../saved_models/IDS/'+name+'_only_src4')
        
        
        
        
        f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
        onlysrc_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
        y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
        for fpr in [0.001,0.01,0.1]:
            scores = scores_trg[:,1]
        #     fpr = 0.01
            benign_scores = scores[y_trg==0]
            benign_scores_sorted = np.sort(benign_scores)
            thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
            thr = benign_scores_sorted[-thr_ind]
            print (thr)
            mal_scores = scores[y_trg==1]
            tpr = np.sum(mal_scores>thr)/len(mal_scores)
            print('TPR:',tpr)
            onlysrc_res[name].append((fpr,tpr))
            
            
        
        
        ########################### DA
        base_lr = 0.0001
        # optimizer = torch.optim.Adam(net.parameters(),lr=base_lr)
        optimizer = tf.keras.optimizers.Adam(lr=base_lr)
        grads = []
        for v in net.trainable_variables:
            grads.append(np.zeros(v.shape))
        optimizer.apply_gradients(zip(grads,net.trainable_variables))

        tsolver = Solver(optimizer,net,base_lr)

        # trg_preds = get_logits(x_target,y_target,tsolver)
        trg_gts = y_trg
        trg_data = x_trg
        src_gts = y_src
        src_data = x_src
        t_labels = np.array(trg_gts)
        l_trg = t_labels
        
        s_labels = np.array(src_gts)
        l_src = s_labels
        trg_size = len(trg_data)
        n_classes = 2
        
        trg_gt_class_percentage0 = np.zeros(n_classes)
        for i in range(n_classes):
            trg_gt_class_percentage0[i] = np.sum(t_labels==i)/len(t_labels)
        
        trg_gt_class_percentage = np.zeros(n_classes)
        for i in range(n_classes):
#             trg_gt_class_percentage[i] = np.sum(t_labels==i)/len(t_labels)
            trg_gt_class_percentage[i] = np.sum(s_labels==i)/len(s_labels)
        
        DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage,mode=1)
        
#         logits_target1 = get_logits(x_target,y_target,tsolver)
#         yhat_target1 = logits_target1.argmax(axis=1)
        
        yhat_target1,logits_target1 = test(x_trg,y_trg,net,ret=True)
                                         
        
#         net.save('../../saved_models/IDS/'+name+'_pppl4')
        print('-----___________________________________________===== MODE 1')
        f1_m1,auprc_m1, acc_m1 = calc_scores(x_trg,y_trg,net,draw=False)
#         pppl_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
        y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
        for fpr in [0.001,0.01,0.1]:
            scores = scores_trg[:,1]
        #     fpr = 0.01
            benign_scores = scores[y_trg==0]
            benign_scores_sorted = np.sort(benign_scores)
            thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
            thr = benign_scores_sorted[-thr_ind]
            print (thr)
            mal_scores = scores[y_trg==1]
            tpr = np.sum(mal_scores>thr)/len(mal_scores)
            print('TPR:',tpr)
#             pppl_res[name].append((fpr,tpr))
            
            
        net = tf.keras.models.load_model('../../saved_models/IDS/'+name+'_only_src4')
        
        
        base_lr = 0.0001
        # optimizer = torch.optim.Adam(net.parameters(),lr=base_lr)
        optimizer = tf.keras.optimizers.Adam(lr=base_lr)
        grads = []
        for v in net.trainable_variables:
            grads.append(np.zeros(v.shape))
        optimizer.apply_gradients(zip(grads,net.trainable_variables))

        tsolver = Solver(optimizer,net,base_lr)

        DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage,mode=2)
        
#         logits_target1 = get_logits(x_target,y_target,tsolver)
#         yhat_target1 = logits_target1.argmax(axis=1)
        
        yhat_target2,logits_target2 = test(x_trg,y_trg,net,ret=True)
                                         
        
#         net.save('../../saved_models/IDS/'+name+'_pppl4')
        print('-----___________________________________________===== MODE 2')
        f1_m2,auprc_m2,acc_m2 = calc_scores(x_trg,y_trg,net,draw=False)
#         pppl_res[name] = [('f1',f1),('auprc',auprc),('acc',acc)]
        
        y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
        for fpr in [0.001,0.01,0.1]:
            scores = scores_trg[:,1]
        #     fpr = 0.01
            benign_scores = scores[y_trg==0]
            benign_scores_sorted = np.sort(benign_scores)
            thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
            thr = benign_scores_sorted[-thr_ind]
            print (thr)
            mal_scores = scores[y_trg==1]
            tpr = np.sum(mal_scores>thr)/len(mal_scores)
            print('TPR:',tpr)
#             pppl_res[name].append((fpr,tpr))
            
        
        
        print('--------------------------------------------------------------------------------------------')
        print('--------------------------------------------------------------------------------------------')
        def model_selection(x_trg,yhat_target1,x_src,y_src,y_src_onehot):
            net1 = PacketModel()
            net1._set_inputs(tf.TensorSpec([None,timesteps*num_input]))

            base_lr = 0.0001
            optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
            grads = []
            for v in net1.trainable_variables:
                grads.append(np.zeros(v.shape))
            optimizer.apply_gradients(zip(grads,net1.trainable_variables))

            tsolver1 = Solver(optimizer,net1,base_lr)

            yhat_target1_onehot = np.zeros((len(yhat_target1),2),np.float32)
            yhat_target1_onehot[range(len(yhat_target1)),yhat_target1.astype(np.int32)] = 1.

            dhandler = DataHandler(x_trg,yhat_target1_onehot,None,batch_size=256,shuffle=True)


            nb_epochs = 6
            batch_size = 256
            total_batch = len(x_trg)//batch_size
            if len(x_trg) % batch_size!=0:
                total_batch+=1

            for i in range(nb_epochs):
                pos_inds = yhat_target1==1
                x_src_pos = x_trg[pos_inds]
                y_src_pos = yhat_target1_onehot[pos_inds]
                x_src_neg = x_trg[~pos_inds]
                y_src_neg = yhat_target1_onehot[~pos_inds]
                p = np.random.permutation(len(x_src_neg))
                x_src_neg = x_src_neg[p]
                y_src_neg = y_src_neg[p]
                pos_len = len(x_src_pos)

                src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
                                                   ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

                train_model2(total_batch,src_dhandler,tsolver1)

    #         for i in range(5):
    #             train_model2(100,dhandler,tsolver1)

            _,logits_train_1 = test(x_src,y_src,net1,ret=True)
            err1 = np.sum(np.abs(logits_train_1 - y_src_onehot)**2,axis=1)
            err1 = np.mean(err1)
            return err1
        err1 = model_selection(x_trg,yhat_target1,x_src,y_src,y_src_onehot)
        err2 = model_selection(x_trg,yhat_target2,x_src,y_src,y_src_onehot)
        print('err1: ',err1, 'err2: ',err2)
        print('f1_m1: ',f1_m1, 'f1_m2: ',f1_m2)
        final_f1 = f1_m1 if err1<err2 else f1_m2
        final_auprc = auprc_m1 if err1<err2 else auprc_m2
        final_acc = acc_m1 if err1<err2 else acc_m2
        pppl_res[name] = [('f1',final_f1),('auprc',final_auprc),('acc',final_acc)]
        print('+++++++++++++++++++++++++++++++')
        print(name,pppl_res[name])
        print('+++++++++++++++++++++++++++++++')
# Out:
# ************************************************** wednesday tuesday
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00000.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00001.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00002.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00003.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00004.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00005.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00006.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00007.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00008.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00009.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00010.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00011.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00012.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00013.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00014.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00015.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00016.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00017.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00018.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00019.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00020.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00021.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00022.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00023.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00024.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00025.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00026.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00027.npy
# ../../../anomaly_datasets/IDS2017/packet_based/wednesday/part_00028.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00000.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00001.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00002.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00003.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00004.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00005.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00006.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00007.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00008.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00009.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00010.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00011.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00012.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00013.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00014.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00015.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00016.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00017.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00018.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00019.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00020.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00021.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00022.npy
# ../../../anomaly_datasets/IDS2017/packet_based/tuesday/part_00023.npy
# (704104, 580) (704104,) (591880, 580) (591880,)
# (685241, 580) (685241,) (573544, 580) (573544,)
# mal rate in src 0.18153175306206137
# mal rate in trg 0.021738523984210452
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea099450>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea099450>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea099450>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea099450>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
#  iter: 2677/2677 ETA: 0:00 loss: 0.0450
#  iter: 2677/2677 ETA: 0:00 loss: 0.0198
#  iter: 2677/2677 ETA: 0:00 loss: 0.0156
#  iter: 2677/2677 ETA: 0:00 loss: 0.0132
#  iter: 2677/2677 ETA: 0:00 loss: 0.0117
#  iter: 2677/2677 ETA: 0:00 loss: 0.0103
# WARNING:tensorflow:AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7fd1e9fdf830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <function canonicalize_signatures.<locals>.signature_wrapper at 0x7fd1e9fdf830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# INFO:tensorflow:Assets written to: ../../saved_models/IDS/we_tu_only_src4/assets
# accuracy: 0.9758832800970806
# accuracy: 0.9758832800970806
# f1 score: 0.014814814814814814
# AUPRC: 0.22267290450807337
# accuracy: 0.9758832800970806
# 0.6277928948402405
# TPR: 0.0019249278152069298
# 0.32891666889190674
# TPR: 0.11324991979467437
# 0.059841882437467575
# TPR: 0.8658966955405839
# ######################################### 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.00
# accuracy: 0.9758832800970806
# %%%%%%% 0.3195864581557018
# len of big_cond 31546 len of trg weights 286772
# len of correcT_indices 239720 correct mals: 5620
# >>>>>>>>>>>>>>>>>>>>>>>>>>18.4492 iter: 0 elapssed time: 1.2452993392944336
# (318318, 580) (318318,) (318318,)
# ------------ 115142
# epoch: 1/1 ETA: 0:00 loss: 0.0439
# current accuracy on target domain:  accuracy: 0.9743350117863668
# ######################################### 2
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.06
# accuracy: 0.9743350117863668
# %%%%%%% 0.3195864581557018
# len of big_cond 37281 len of trg weights 286772
# len of correcT_indices 238066 correct mals: 4793
# >>>>>>>>>>>>>>>>>>>>>>>>>>17.8590 iter: 0 elapssed time: 4.95210599899292
# (324053, 580) (324053,) (324053,)
# ------------ 117840
# epoch: 1/1 ETA: 0:00 loss: 0.0450
# ######################################### 4
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.10
# accuracy: 0.9752172457562105
# %%%%%%% 0.3195864581557018
# len of big_cond 43017 len of trg weights 286772
# len of correcT_indices 238488 correct mals: 5004
# >>>>>>>>>>>>>>>>>>>>>>>>>>17.6605 iter: 0 elapssed time: 7.6469995975494385
# (329789, 580) (329789,) (329789,)
# ------------ 119944
# epoch: 1/1 ETA: 0:00 loss: 0.0452
# ######################################### 6
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.15
# accuracy: 0.9623673161954445
# %%%%%%% 0.3195864581557018
# len of big_cond 48752 len of trg weights 286772
# len of correcT_indices 237750 correct mals: 4635
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.9490 iter: 0 elapssed time: 10.23215103149414
# (335524, 580) (335524,) (335524,)
# ------------ 121320
# epoch: 1/1 ETA: 0:00 loss: 0.0456
# ######################################### 8
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.19
# accuracy: 0.9443878760827417
# %%%%%%% 0.3195864581557018
# len of big_cond 54488 len of trg weights 286772
# len of correcT_indices 239000 correct mals: 5260
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.8955 iter: 0 elapssed time: 12.582035779953003
# (341260, 580) (341260,) (341260,)
# ------------ 124022
# epoch: 1/1 ETA: 0:00 loss: 0.0403
# current accuracy on target domain:  accuracy: 0.9311683148982467
# ######################################### 10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.25
# accuracy: 0.9311683148982467
# %%%%%%% 0.3195864581557018
# len of big_cond 60223 len of trg weights 286772
# len of correcT_indices 239146 correct mals: 5333
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.7195 iter: 0 elapssed time: 16.0665602684021
# (346995, 580) (346995,) (346995,)
# ------------ 125776
# epoch: 1/1 ETA: 0:00 loss: 0.0338
# ######################################### 12
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.29
# accuracy: 0.9067028859163377
# %%%%%%% 0.3195864581557018
# len of big_cond 65959 len of trg weights 286772
# len of correcT_indices 238892 correct mals: 5206
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.6952 iter: 0 elapssed time: 18.407666444778442
# (352731, 580) (352731,) (352731,)
# ------------ 128026
# epoch: 1/1 ETA: 0:00 loss: 0.0201
# ######################################### 14
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.33
# accuracy: 0.9231514931722762
# %%%%%%% 0.3195864581557018
# len of big_cond 71694 len of trg weights 286772
# len of correcT_indices 240068 correct mals: 5794
# >>>>>>>>>>>>>>>>>>>>>>>>>>17.1353 iter: 0 elapssed time: 20.756763696670532
# (358466, 580) (358466,) (358466,)
# ------------ 130400
# epoch: 1/1 ETA: 0:00 loss: 0.0239
# ######################################### 16
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.36
# accuracy: 0.9182207467953636
# %%%%%%% 0.3195864581557018
# len of big_cond 77429 len of trg weights 286772
# len of correcT_indices 239390 correct mals: 5455
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.7508 iter: 0 elapssed time: 23.059800624847412
# (364201, 580) (364201,) (364201,)
# ------------ 132062
# epoch: 1/1 ETA: 0:00 loss: 0.0187
# current accuracy on target domain:  accuracy: 0.9249752416553917
# ######################################### 18
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.42
# accuracy: 0.9249752416553917
# %%%%%%% 0.3195864581557018
# len of big_cond 83165 len of trg weights 286772
# len of correcT_indices 239770 correct mals: 5645
# >>>>>>>>>>>>>>>>>>>>>>>>>>17.3943 iter: 0 elapssed time: 26.64890694618225
# (369937, 580) (369937,) (369937,)
# ------------ 134308
# epoch: 1/1 ETA: 0:00 loss: 0.0274
# ######################################### 20
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.46
# accuracy: 0.8920850013250945
# %%%%%%% 0.3195864581557018
# len of big_cond 88900 len of trg weights 286772
# len of correcT_indices 239228 correct mals: 5374
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.9753 iter: 0 elapssed time: 28.97676420211792
# (375672, 580) (375672,) (375672,)
# ------------ 136172
# epoch: 1/1 ETA: 0:00 loss: 0.0174
# ######################################### 22
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.50
# accuracy: 0.9066191957373803
# %%%%%%% 0.3195864581557018
# len of big_cond 94636 len of trg weights 286772
# len of correcT_indices 239608 correct mals: 5564
# >>>>>>>>>>>>>>>>>>>>>>>>>>17.0527 iter: 0 elapssed time: 31.335937023162842
# (381408, 580) (381408,) (381408,)
# ------------ 138094
# epoch: 1/1 ETA: 0:00 loss: 0.0175
# ######################################### 24
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.54
# accuracy: 0.9115638904774525
# %%%%%%% 0.3195864581557018
# len of big_cond 100371 len of trg weights 286772
# len of correcT_indices 239644 correct mals: 5582
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.9959 iter: 0 elapssed time: 33.71844244003296
# (387143, 580) (387143,) (387143,)
# ------------ 140818
# epoch: 1/1 ETA: 0:00 loss: 0.0170
# current accuracy on target domain:  accuracy: 0.9158146541503355
# ######################################### 26
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.60
# accuracy: 0.9158146541503355
# %%%%%%% 0.3195864581557018
# len of big_cond 106107 len of trg weights 286772
# len of correcT_indices 239834 correct mals: 5677
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.8340 iter: 0 elapssed time: 37.28484797477722
# (392879, 580) (392879,) (392879,)
# ------------ 142896
# epoch: 1/1 ETA: 0:00 loss: 0.0181
# ######################################### 28
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.64
# accuracy: 0.9201456209113861
# %%%%%%% 0.3195864581557018
# len of big_cond 111842 len of trg weights 286772
# len of correcT_indices 239756 correct mals: 5638
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.9105 iter: 0 elapssed time: 39.724082946777344
# (398614, 580) (398614,) (398614,)
# ------------ 144394
# epoch: 1/1 ETA: 0:00 loss: 0.0210
# ######################################### 30
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.68
# accuracy: 0.9078048066059448
# %%%%%%% 0.3195864581557018
# len of big_cond 117577 len of trg weights 286772
# len of correcT_indices 239602 correct mals: 5561
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.5024 iter: 0 elapssed time: 42.20192217826843
# (404349, 580) (404349,) (404349,)
# ------------ 146726
# epoch: 1/1 ETA: 0:00 loss: 0.0178
# ######################################### 32
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.72
# accuracy: 0.904084080733126
# %%%%%%% 0.3195864581557018
# len of big_cond 123313 len of trg weights 286772
# len of correcT_indices 239846 correct mals: 5683
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.0526 iter: 0 elapssed time: 44.67122149467468
# (410085, 580) (410085,) (410085,)
# ------------ 148918
# epoch: 1/1 ETA: 0:00 loss: 0.0149
# current accuracy on target domain:  accuracy: 0.9131993360579136
# ######################################### 34
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.78
# accuracy: 0.9131993360579136
# %%%%%%% 0.3195864581557018
# len of big_cond 129049 len of trg weights 286772
# len of correcT_indices 240014 correct mals: 5767
# >>>>>>>>>>>>>>>>>>>>>>>>>>16.1489 iter: 0 elapssed time: 48.307234048843384
# (415821, 580) (415821,) (415821,)
# ------------ 151500
# epoch: 1/1 ETA: 0:00 loss: 0.0177
# ######################################### 36
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.83
# accuracy: 0.9082476671362616
# %%%%%%% 0.3195864581557018
# len of big_cond 134784 len of trg weights 286772
# len of correcT_indices 240126 correct mals: 5823
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.5619 iter: 0 elapssed time: 50.78307104110718
# (421556, 580) (421556,) (421556,)
# ------------ 152942
# epoch: 1/1 ETA: 0:00 loss: 0.0157
# ######################################### 38
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.87
# accuracy: 0.9068632920926729
# %%%%%%% 0.3195864581557018
# len of big_cond 140519 len of trg weights 286772
# len of correcT_indices 240074 correct mals: 5797
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.7851 iter: 0 elapssed time: 53.258092164993286
# (427291, 580) (427291,) (427291,)
# ------------ 155392
# epoch: 1/1 ETA: 0:00 loss: 0.0158
# ######################################### 40
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.91
# accuracy: 0.9104619697878454
# %%%%%%% 0.3195864581557018
# len of big_cond 146255 len of trg weights 286772
# len of correcT_indices 240236 correct mals: 5878
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.8566 iter: 0 elapssed time: 55.8347270488739
# (433027, 580) (433027,) (433027,)
# ------------ 157660
# epoch: 1/1 ETA: 0:00 loss: 0.0168
# current accuracy on target domain:  accuracy: 0.8860209504414657
# ######################################### 42
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.97
# accuracy: 0.8860209504414657
# %%%%%%% 0.3195864581557018
# len of big_cond 151990 len of trg weights 286772
# len of correcT_indices 240116 correct mals: 5818
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.6872 iter: 0 elapssed time: 59.5199716091156
# (438762, 580) (438762,) (438762,)
# ------------ 159036
# epoch: 1/1 ETA: 0:00 loss: 0.0154
# ######################################### 44
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.01
# accuracy: 0.8996519883391684
# %%%%%%% 0.3195864581557018
# len of big_cond 157725 len of trg weights 286772
# len of correcT_indices 240130 correct mals: 5825
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.8535 iter: 0 elapssed time: 62.10450267791748
# (444497, 580) (444497,) (444497,)
# ------------ 160954
# epoch: 1/1 ETA: 0:00 loss: 0.0173
# ######################################### 46
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.06
# accuracy: 0.876037409509994
# %%%%%%% 0.3195864581557018
# len of big_cond 163461 len of trg weights 286772
# len of correcT_indices 240048 correct mals: 5784
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.6576 iter: 0 elapssed time: 64.6810450553894
# (450233, 580) (450233,) (450233,)
# ------------ 163158
# epoch: 1/1 ETA: 0:00 loss: 0.0141
# ######################################### 48
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.10
# accuracy: 0.8911888189920912
# %%%%%%% 0.3195864581557018
# len of big_cond 169197 len of trg weights 286772
# len of correcT_indices 240328 correct mals: 5924
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.7113 iter: 0 elapssed time: 67.29134726524353
# (455969, 580) (455969,) (455969,)
# ------------ 164838
# epoch: 1/1 ETA: 0:00 loss: 0.0161
# current accuracy on target domain:  accuracy: 0.8866834976915459
# ######################################### 50
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.16
# accuracy: 0.8866834976915459
# %%%%%%% 0.3195864581557018
# len of big_cond 174932 len of trg weights 286772
# len of correcT_indices 240328 correct mals: 5924
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.6272 iter: 0 elapssed time: 71.0364191532135
# (461704, 580) (461704,) (461704,)
# ------------ 167756
# epoch: 1/1 ETA: 0:00 loss: 0.0156
# ######################################### 52
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.21
# accuracy: 0.8757723906099619
# %%%%%%% 0.3195864581557018
# len of big_cond 180667 len of trg weights 286772
# len of correcT_indices 240362 correct mals: 5941
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.5933 iter: 0 elapssed time: 73.67062711715698
# (467439, 580) (467439,) (467439,)
# ------------ 169638
# epoch: 1/1 ETA: 0:00 loss: 0.0142
# ######################################### 54
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.25
# accuracy: 0.8669082058220468
# %%%%%%% 0.3195864581557018
# len of big_cond 186403 len of trg weights 286772
# len of correcT_indices 240276 correct mals: 5898
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.7111 iter: 0 elapssed time: 76.3073480129242
# (473175, 580) (473175,) (473175,)
# ------------ 171686
# epoch: 1/1 ETA: 0:00 loss: 0.0124
# ######################################### 56
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.30
# accuracy: 0.8685018063130292
# %%%%%%% 0.3195864581557018
# len of big_cond 192138 len of trg weights 286772
# len of correcT_indices 240194 correct mals: 5857
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.9104 iter: 0 elapssed time: 78.92128133773804
# (478910, 580) (478910,) (478910,)
# ------------ 173772
# epoch: 1/1 ETA: 0:00 loss: 0.0126
# current accuracy on target domain:  accuracy: 0.8688016961209603
# ######################################### 58
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.36
# accuracy: 0.8688016961209603
# %%%%%%% 0.3195864581557018
# len of big_cond 197874 len of trg weights 286772
# len of correcT_indices 240244 correct mals: 5882
# >>>>>>>>>>>>>>>>>>>>>>>>>>15.9389 iter: 0 elapssed time: 82.75132703781128
# (484646, 580) (484646,) (484646,)
# ------------ 175866
# epoch: 1/1 ETA: 0:00 loss: 0.0125
# ######################################### 60
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.40
# accuracy: 0.8629364094123555
# %%%%%%% 0.3195864581557018
# len of big_cond 203609 len of trg weights 286772
# len of correcT_indices 247466 correct mals: 5146
# >>>>>>>>>>>>>>>>>>>>>>>>>>13.2396 iter: 0 elapssed time: 85.52123236656189
# (490381, 580) (490381,) (490381,)
# ------------ 490381
# epoch: 1/1 ETA: 0:02 loss: 0.0086
# ######################################### 62
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.47
# accuracy: 0.8874715802100623
# %%%%%%% 0.3195864581557018
# len of big_cond 209345 len of trg weights 286772
# len of correcT_indices 254502 correct mals: 4550
# >>>>>>>>>>>>>>>>>>>>>>>>>>10.7306 iter: 0 elapssed time: 89.3212194442749
# (496117, 580) (496117,) (496117,)
# ------------ 496117
# epoch: 1/1 ETA: 0:02 loss: 0.0067
# ######################################### 64
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.53
# accuracy: 0.8993834823483464
# %%%%%%% 0.3195864581557018
# len of big_cond 215080 len of trg weights 286772
# len of correcT_indices 257918 correct mals: 4123
# >>>>>>>>>>>>>>>>>>>>>>>>>>9.4890 iter: 0 elapssed time: 93.13911604881287
# (501852, 580) (501852,) (501852,)
# ------------ 501852
# epoch: 1/1 ETA: 0:02 loss: 0.0057
# current accuracy on target domain:  accuracy: 0.9027310895066464
# ######################################### 66
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.61
# accuracy: 0.9027310895066464
# %%%%%%% 0.3195864581557018
# len of big_cond 220815 len of trg weights 286772
# len of correcT_indices 258878 correct mals: 4375
# >>>>>>>>>>>>>>>>>>>>>>>>>>9.1950 iter: 0 elapssed time: 98.12720608711243
# (507587, 580) (507587,) (507587,)
# ------------ 507587
# epoch: 1/1 ETA: 0:02 loss: 0.0052
# ######################################### 68
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.68
# accuracy: 0.9065703764663217
# %%%%%%% 0.3195864581557018
# len of big_cond 226551 len of trg weights 286772
# len of correcT_indices 259979 correct mals: 4256
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.8046 iter: 0 elapssed time: 101.95697116851807
# (513323, 580) (513323,) (513323,)
# ------------ 513323
# epoch: 1/1 ETA: 0:02 loss: 0.0048
# ######################################### 70
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.74
# accuracy: 0.9098621901719833
# %%%%%%% 0.3195864581557018
# len of big_cond 232286 len of trg weights 286772
# len of correcT_indices 260923 correct mals: 4244
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.4930 iter: 0 elapssed time: 105.9101333618164
# (519058, 580) (519058,) (519058,)
# ------------ 519058
# epoch: 1/1 ETA: 0:02 loss: 0.0043
# ######################################### 72
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.82
# accuracy: 0.9126623240762697
# %%%%%%% 0.3195864581557018
# len of big_cond 238022 len of trg weights 286772
# len of correcT_indices 261726 correct mals: 4141
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.2379 iter: 0 elapssed time: 110.4850127696991
# (524794, 580) (524794,) (524794,)
# ------------ 524794
# epoch: 1/1 ETA: 0:02 loss: 0.0041
# current accuracy on target domain:  accuracy: 0.9145802240107124
# ######################################### 74
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.91
# accuracy: 0.9145802240107124
# %%%%%%% 0.3195864581557018
# len of big_cond 243756 len of trg weights 286772
# len of correcT_indices 262276 correct mals: 4109
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.0790 iter: 0 elapssed time: 115.78389048576355
# (530528, 580) (530528,) (530528,)
# ------------ 530528
# epoch: 1/1 ETA: 0:02 loss: 0.0038
# ######################################### 76
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.98
# accuracy: 0.915291590531851
# %%%%%%% 0.3195864581557018
# len of big_cond 249490 len of trg weights 286772
# len of correcT_indices 262480 correct mals: 4335
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.0805 iter: 0 elapssed time: 119.7810730934143
# (536262, 580) (536262,) (536262,)
# ------------ 536262
# epoch: 1/1 ETA: 0:02 loss: 0.0037
# ######################################### 78
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.04
# accuracy: 0.915462457980556
# %%%%%%% 0.3195864581557018
# len of big_cond 255176 len of trg weights 286772
# len of correcT_indices 262529 correct mals: 4234
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.0243 iter: 0 elapssed time: 123.78530216217041
# (541948, 580) (541948,) (541948,)
# ------------ 541948
# epoch: 1/1 ETA: 0:02 loss: 0.0035
# ######################################### 80
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.11
# accuracy: 0.9130633395171077
# %%%%%%% 0.3195864581557018
# len of big_cond 259018 len of trg weights 286772
# len of correcT_indices 261841 correct mals: 4095
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.2728 iter: 0 elapssed time: 127.90704154968262
# (545790, 580) (545790,) (545790,)
# ------------ 545790
# epoch: 1/1 ETA: 0:02 loss: 0.0034
# current accuracy on target domain:  accuracy: 0.9126937078933787
# ######################################### 82
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.20
# accuracy: 0.9126937078933787
# %%%%%%% 0.3195864581557018
# len of big_cond 259896 len of trg weights 286772
# len of correcT_indices 261735 correct mals: 4137
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.4138 iter: 0 elapssed time: 133.7176594734192
# (546668, 580) (546668,) (546668,)
# ------------ 546668
# epoch: 1/1 ETA: 0:03 loss: 0.0033
# ######################################### 84
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.29
# accuracy: 0.9132481553289722
# %%%%%%% 0.3195864581557018
# len of big_cond 260834 len of trg weights 286772
# len of correcT_indices 261894 correct mals: 4425
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.5564 iter: 0 elapssed time: 138.90897488594055
# (547606, 580) (547606,) (547606,)
# ------------ 547606
# epoch: 1/1 ETA: 0:03 loss: 0.0033
# ######################################### 86
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.38
# accuracy: 0.912951752611831
# %%%%%%% 0.3195864581557018
# len of big_cond 261740 len of trg weights 286772
# len of correcT_indices 261809 correct mals: 4566
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.7423 iter: 0 elapssed time: 144.3595519065857
# (548512, 580) (548512,) (548512,)
# ------------ 548512
# epoch: 1/1 ETA: 0:02 loss: 0.0033
# ######################################### 88
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.46
# accuracy: 0.9130040589736794
# %%%%%%% 0.3195864581557018
# len of big_cond 262506 len of trg weights 286772
# len of correcT_indices 261824 correct mals: 4679
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.8646 iter: 0 elapssed time: 148.69555187225342
# (549278, 580) (549278,) (549278,)
# ------------ 549278
# epoch: 1/1 ETA: 0:02 loss: 0.0034
# current accuracy on target domain:  accuracy: 0.9125890951696818
# accuracy: 0.9125890951696818
# -----___________________________________________===== MODE 1
# accuracy: 0.9125890951696818
# accuracy: 0.9125890951696818
# f1 score: 0.2717103925157616
# AUPRC: 0.149255970781199
# accuracy: 0.9125890951696818
# 1.0961285829544067
# TPR: 0.021495027269810715
# 1.034476399421692
# TPR: 0.09785049727301892
# 0.19097977876663208
# TPR: 0.9541225537375682
# ######################################### 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.00
# accuracy: 0.9758832800970806
# %%%%%%% 0.21231191833497984
# len of big_cond 31546 len of trg weights 286772
# len of correcT_indices 254697 correct mals: 5418
# >>>>>>>>>>>>>>>>>>>>>>>>>>13.0223 iter: 0 elapssed time: 1.2748682498931885
# (318318, 580) (318318,) (318318,)
# ------------ 112468
# epoch: 1/1 ETA: 0:00 loss: 0.0341
# current accuracy on target domain:  accuracy: 0.9755799031983596
# ######################################### 2
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.06
# accuracy: 0.9755799031983596
# %%%%%%% 0.13746453423392516
# len of big_cond 37281 len of trg weights 286772
# len of correcT_indices 263234 correct mals: 4320
# >>>>>>>>>>>>>>>>>>>>>>>>>>8.7390 iter: 0 elapssed time: 4.893886089324951
# (324053, 580) (324053,) (324053,)
# ------------ 111262
# epoch: 1/1 ETA: 0:00 loss: 0.0271
# ######################################### 4
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.10
# accuracy: 0.9745093663258617
# %%%%%%% 0.08736656852109628
# len of big_cond 43017 len of trg weights 286772
# len of correcT_indices 269791 correct mals: 4007
# >>>>>>>>>>>>>>>>>>>>>>>>>>6.0534 iter: 0 elapssed time: 7.128042221069336
# (329789, 580) (329789,) (329789,)
# ------------ 109126
# epoch: 1/1 ETA: 0:00 loss: 0.0206
# ######################################### 6
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.14
# accuracy: 0.9738851770744703
# %%%%%%% 0.0570285798876888
# len of big_cond 48752 len of trg weights 286772
# len of correcT_indices 273583 correct mals: 3728
# >>>>>>>>>>>>>>>>>>>>>>>>>>4.1783 iter: 0 elapssed time: 9.456779479980469
# (335524, 580) (335524,) (335524,)
# ------------ 109366
# epoch: 1/1 ETA: 0:00 loss: 0.0161
# ######################################### 8
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.18
# accuracy: 0.9740002510705369
# %%%%%%% 0.03432950196702125
# len of big_cond 54488 len of trg weights 286772
# len of correcT_indices 275412 correct mals: 3015
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.8759 iter: 0 elapssed time: 11.972213983535767
# (341260, 580) (341260,) (341260,)
# ------------ 108424
# epoch: 1/1 ETA: 0:00 loss: 0.0131
# current accuracy on target domain:  accuracy: 0.9722288089492698
# ######################################### 10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.24
# accuracy: 0.9722288089492698
# %%%%%%% 0.021482285427659016
# len of big_cond 60223 len of trg weights 286772
# len of correcT_indices 276340 correct mals: 2558
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.0208 iter: 0 elapssed time: 15.393079042434692
# (346995, 580) (346995,) (346995,)
# ------------ 107968
# epoch: 1/1 ETA: 0:00 loss: 0.0112
# ######################################### 12
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.27
# accuracy: 0.9741815797916115
# %%%%%%% 0.011053947280984303
# len of big_cond 65959 len of trg weights 286772
# len of correcT_indices 277817 correct mals: 2549
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.5904 iter: 0 elapssed time: 17.624265432357788
# (352731, 580) (352731,) (352731,)
# ------------ 107334
# epoch: 1/1 ETA: 0:00 loss: 0.0102
# ######################################### 14
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.31
# accuracy: 0.9739026125284198
# %%%%%%% 0.00533167045166098
# len of big_cond 71694 len of trg weights 286772
# len of correcT_indices 278552 correct mals: 2506
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.4227 iter: 0 elapssed time: 19.863863229751587
# (358466, 580) (358466,) (358466,)
# ------------ 107448
# epoch: 1/1 ETA: 0:00 loss: 0.0100
# ######################################### 16
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.35
# accuracy: 0.9750603266706652
# %%%%%%% 0.0009461116875614482
# len of big_cond 77429 len of trg weights 286772
# len of correcT_indices 278698 correct mals: 2129
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.2566 iter: 0 elapssed time: 22.090769052505493
# (364201, 580) (364201,) (364201,)
# ------------ 107510
# epoch: 1/1 ETA: 0:00 loss: 0.0097
# current accuracy on target domain:  accuracy: 0.9751091459417237
# ######################################### 18
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.40
# accuracy: 0.9751091459417237
# %%%%%%% 0.004415782707536786
# len of big_cond 83165 len of trg weights 286772
# len of correcT_indices 279213 correct mals: 2138
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.0846 iter: 0 elapssed time: 25.42988419532776
# (369937, 580) (369937,) (369937,)
# ------------ 107846
# epoch: 1/1 ETA: 0:00 loss: 0.0092
# ######################################### 20
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.44
# accuracy: 0.9745058792350718
# %%%%%%% 0.00785511133243148
# len of big_cond 88900 len of trg weights 286772
# len of correcT_indices 278900 correct mals: 1735
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.1001 iter: 0 elapssed time: 27.664662837982178
# (375672, 580) (375672,) (375672,)
# ------------ 107594
# epoch: 1/1 ETA: 0:00 loss: 0.0085
# ######################################### 22
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.48
# accuracy: 0.9744500857824334
# %%%%%%% 0.008463302522271302
# len of big_cond 94636 len of trg weights 286772
# len of correcT_indices 279380 correct mals: 1931
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.9774 iter: 0 elapssed time: 29.94139337539673
# (381408, 580) (381408,) (381408,)
# ------------ 107306
# epoch: 1/1 ETA: 0:00 loss: 0.0086
# ######################################### 24
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.52
# accuracy: 0.9729785334690974
# %%%%%%% 0.007144096123895459
# len of big_cond 100371 len of trg weights 286772
# len of correcT_indices 279284 correct mals: 1978
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.0481 iter: 0 elapssed time: 32.12420916557312
# (387143, 580) (387143,) (387143,)
# ------------ 107202
# epoch: 1/1 ETA: 0:00 loss: 0.0082
# current accuracy on target domain:  accuracy: 0.9743106021508376
# ######################################### 26
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.57
# accuracy: 0.9743106021508376
# %%%%%%% 0.009400878445417295
# len of big_cond 106106 len of trg weights 286772
# len of correcT_indices 279050 correct mals: 1699
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.0490 iter: 0 elapssed time: 35.59890675544739
# (392878, 580) (392878,) (392878,)
# ------------ 108076
# epoch: 1/1 ETA: 0:00 loss: 0.0081
# ######################################### 28
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.61
# accuracy: 0.9718626644163307
# %%%%%%% 0.009264977401853808
# len of big_cond 111842 len of trg weights 286772
# len of correcT_indices 278738 correct mals: 1553
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.1829 iter: 0 elapssed time: 37.875943660736084
# (398614, 580) (398614,) (398614,)
# ------------ 108174
# epoch: 1/1 ETA: 0:00 loss: 0.0078
# ######################################### 30
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.65
# accuracy: 0.9717929226005328
# %%%%%%% 0.0065963736684163735
# len of big_cond 117578 len of trg weights 286772
# len of correcT_indices 279018 correct mals: 1884
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.1788 iter: 0 elapssed time: 40.13501858711243
# (404350, 580) (404350,) (404350,)
# ------------ 108586
# epoch: 1/1 ETA: 0:00 loss: 0.0076
# ######################################### 32
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.69
# accuracy: 0.9692822172318079
# %%%%%%% 0.0029331967163717908
# len of big_cond 123313 len of trg weights 286772
# len of correcT_indices 278471 correct mals: 1873
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.3608 iter: 0 elapssed time: 42.366424322128296
# (410085, 580) (410085,) (410085,)
# ------------ 109558
# epoch: 1/1 ETA: 0:00 loss: 0.0079
# current accuracy on target domain:  accuracy: 0.9686894117975255
# ######################################### 34
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.74
# accuracy: 0.9686894117975255
# %%%%%%% 0.0017540453116870643
# len of big_cond 129048 len of trg weights 286772
# len of correcT_indices 277972 correct mals: 1708
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.5614 iter: 0 elapssed time: 45.8599910736084
# (415820, 580) (415820,) (415820,)
# ------------ 109520
# epoch: 1/1 ETA: 0:00 loss: 0.0075
# ######################################### 36
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.78
# accuracy: 0.9663495738775055
# %%%%%%% 0.001701324545331534
# len of big_cond 134784 len of trg weights 286772
# len of correcT_indices 277722 correct mals: 1831
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.6508 iter: 0 elapssed time: 48.100380420684814
# (421556, 580) (421556,) (421556,)
# ------------ 110340
# epoch: 1/1 ETA: 0:00 loss: 0.0072
# ######################################### 38
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.82
# accuracy: 0.9631763212587003
# %%%%%%% 0.005387989656450695
# len of big_cond 140519 len of trg weights 286772
# len of correcT_indices 276843 correct mals: 1656
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.9094 iter: 0 elapssed time: 50.34756016731262
# (427291, 580) (427291,) (427291,)
# ------------ 111360
# epoch: 1/1 ETA: 0:00 loss: 0.0071
# ######################################### 40
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.86
# accuracy: 0.9626602318217957
# %%%%%%% 0.010291057700304813
# len of big_cond 146255 len of trg weights 286772
# len of correcT_indices 276760 correct mals: 1966
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.0827 iter: 0 elapssed time: 52.63141059875488
# (433027, 580) (433027,) (433027,)
# ------------ 111494
# epoch: 1/1 ETA: 0:00 loss: 0.0070
# current accuracy on target domain:  accuracy: 0.9598600979175094
# ######################################### 42
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.91
# accuracy: 0.9598600979175094
# %%%%%%% 0.014273468257648192
# len of big_cond 151990 len of trg weights 286772
# len of correcT_indices 275759 correct mals: 1751
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.3765 iter: 0 elapssed time: 56.06422424316406
# (438762, 580) (438762,) (438762,)
# ------------ 112792
# epoch: 1/1 ETA: 0:00 loss: 0.0068
# ######################################### 44
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.95
# accuracy: 0.9602053199057091
# %%%%%%% 0.01769929326233946
# len of big_cond 157725 len of trg weights 286772
# len of correcT_indices 275664 correct mals: 1949
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.4942 iter: 0 elapssed time: 58.34194564819336
# (444497, 580) (444497,) (444497,)
# ------------ 113918
# epoch: 1/1 ETA: 0:00 loss: 0.0069
# ######################################### 46
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.99
# accuracy: 0.9586500774134156
# %%%%%%% 0.021432229119995524
# len of big_cond 163461 len of trg weights 286772
# len of correcT_indices 275307 correct mals: 2038
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.7077 iter: 0 elapssed time: 60.69561839103699
# (450233, 580) (450233,) (450233,)
# ------------ 115062
# epoch: 1/1 ETA: 0:00 loss: 0.0068
# ######################################### 48
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.03
# accuracy: 0.9590615541266232
# %%%%%%% 0.024229402614061125
# len of big_cond 169196 len of trg weights 286772
# len of correcT_indices 275322 correct mals: 2246
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.7932 iter: 0 elapssed time: 63.02323913574219
# (455968, 580) (455968,) (455968,)
# ------------ 115082
# epoch: 1/1 ETA: 0:00 loss: 0.0066
# current accuracy on target domain:  accuracy: 0.9588837124963385
# ######################################### 50
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.09
# accuracy: 0.9588837124963385
# %%%%%%% 0.02875462029942836
# len of big_cond 174932 len of trg weights 286772
# len of correcT_indices 275409 correct mals: 2614
# >>>>>>>>>>>>>>>>>>>>>>>>>>2.9183 iter: 0 elapssed time: 66.4229691028595
# (461704, 580) (461704,) (461704,)
# ------------ 116530
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# ######################################### 52
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.13
# accuracy: 0.9586954095936842
# %%%%%%% 0.0324704433513571
# len of big_cond 180667 len of trg weights 286772
# len of correcT_indices 275290 correct mals: 2821
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.0542 iter: 0 elapssed time: 68.75883626937866
# (467439, 580) (467439,) (467439,)
# ------------ 118184
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# ######################################### 54
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.17
# accuracy: 0.9568367902026698
# %%%%%%% 0.03726210992191979
# len of big_cond 186403 len of trg weights 286772
# len of correcT_indices 274991 correct mals: 3015
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.2757 iter: 0 elapssed time: 71.1407356262207
# (473175, 580) (473175,) (473175,)
# ------------ 118930
# epoch: 1/1 ETA: 0:00 loss: 0.0062
# ######################################### 56
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.21
# accuracy: 0.9576423081751356
# %%%%%%% 0.037634813895952815
# len of big_cond 192139 len of trg weights 286772
# len of correcT_indices 274644 correct mals: 2868
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.3450 iter: 0 elapssed time: 73.54980325698853
# (478911, 580) (478911,) (478911,)
# ------------ 120014
# epoch: 1/1 ETA: 0:00 loss: 0.0061
# current accuracy on target domain:  accuracy: 0.9575795405409175
# ######################################### 58
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.27
# accuracy: 0.9575795405409175
# %%%%%%% 0.039301701684261746
# len of big_cond 197874 len of trg weights 286772
# len of correcT_indices 274789 correct mals: 3060
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.3324 iter: 0 elapssed time: 77.06345391273499
# (484646, 580) (484646,) (484646,)
# ------------ 120594
# epoch: 1/1 ETA: 0:00 loss: 0.0059
# ######################################### 60
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.30
# accuracy: 0.9570913478303321
# %%%%%%% 0.039301701684261746
# len of big_cond 203609 len of trg weights 286772
# len of correcT_indices 274467 correct mals: 3201
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.4846 iter: 0 elapssed time: 79.4570939540863
# (490381, 580) (490381,) (490381,)
# ------------ 490381
# epoch: 1/1 ETA: 0:02 loss: 0.0053
# ######################################### 62
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.37
# accuracy: 0.9578515336225294
# %%%%%%% 0.039301701684261746
# len of big_cond 209345 len of trg weights 286772
# len of correcT_indices 274685 correct mals: 2753
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.3127 iter: 0 elapssed time: 83.15064930915833
# (496117, 580) (496117,) (496117,)
# ------------ 496117
# epoch: 1/1 ETA: 0:02 loss: 0.0048
# ######################################### 64
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.43
# accuracy: 0.9580886557962424
# %%%%%%% 0.039301701684261746
# len of big_cond 215080 len of trg weights 286772
# len of correcT_indices 274753 correct mals: 2443
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.1337 iter: 0 elapssed time: 86.90242505073547
# (501852, 580) (501852,) (501852,)
# ------------ 501852
# epoch: 1/1 ETA: 0:02 loss: 0.0044
# current accuracy on target domain:  accuracy: 0.9574365698185318
# ######################################### 66
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.51
# accuracy: 0.9574365698185318
# %%%%%%% 0.039301701684261746
# len of big_cond 220816 len of trg weights 286772
# len of correcT_indices 274566 correct mals: 2335
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.1642 iter: 0 elapssed time: 91.81850910186768
# (507588, 580) (507588,) (507588,)
# ------------ 507588
# epoch: 1/1 ETA: 0:02 loss: 0.0042
# ######################################### 68
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.57
# accuracy: 0.9567042807526537
# %%%%%%% 0.039301701684261746
# len of big_cond 226551 len of trg weights 286772
# len of correcT_indices 274356 correct mals: 2469
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.2982 iter: 0 elapssed time: 95.67226529121399
# (513323, 580) (513323,) (513323,)
# ------------ 513323
# epoch: 1/1 ETA: 0:02 loss: 0.0040
# ######################################### 70
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.64
# accuracy: 0.9574261085461621
# %%%%%%% 0.039301701684261746
# len of big_cond 232287 len of trg weights 286772
# len of correcT_indices 274563 correct mals: 2725
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.2877 iter: 0 elapssed time: 99.46489667892456
# (519059, 580) (519059,) (519059,)
# ------------ 519059
# epoch: 1/1 ETA: 0:02 loss: 0.0038
# ######################################### 72
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.70
# accuracy: 0.9577329725356729
# %%%%%%% 0.039301701684261746
# len of big_cond 238022 len of trg weights 286772
# len of correcT_indices 274651 correct mals: 2931
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.3161 iter: 0 elapssed time: 103.36733484268188
# (524794, 580) (524794,) (524794,)
# ------------ 524794
# epoch: 1/1 ETA: 0:02 loss: 0.0037
# current accuracy on target domain:  accuracy: 0.95616029458943
# ######################################### 74
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.79
# accuracy: 0.95616029458943
# %%%%%%% 0.039301701684261746
# len of big_cond 243757 len of trg weights 286772
# len of correcT_indices 274200 correct mals: 2567
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.3726 iter: 0 elapssed time: 108.29563212394714
# (530529, 580) (530529,) (530529,)
# ------------ 530529
# epoch: 1/1 ETA: 0:02 loss: 0.0035
# ######################################### 76
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.85
# accuracy: 0.9565857196657972
# %%%%%%% 0.039301701684261746
# len of big_cond 249492 len of trg weights 286772
# len of correcT_indices 274322 correct mals: 2904
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.4206 iter: 0 elapssed time: 112.17211580276489
# (536264, 580) (536264,) (536264,)
# ------------ 536264
# epoch: 1/1 ETA: 0:02 loss: 0.0034
# ######################################### 78
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.92
# accuracy: 0.9553268798906448
# %%%%%%% 0.039301701684261746
# len of big_cond 255228 len of trg weights 286772
# len of correcT_indices 273961 correct mals: 2755
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.5145 iter: 0 elapssed time: 116.06977033615112
# (542000, 580) (542000,) (542000,)
# ------------ 542000
# epoch: 1/1 ETA: 0:02 loss: 0.0032
# ######################################### 80
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.98
# accuracy: 0.955888301507818
# %%%%%%% 0.039301701684261746
# len of big_cond 260963 len of trg weights 286772
# len of correcT_indices 274122 correct mals: 3031
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.4729 iter: 0 elapssed time: 120.01118421554565
# (547735, 580) (547735,) (547735,)
# ------------ 547735
# epoch: 1/1 ETA: 0:02 loss: 0.0032
# current accuracy on target domain:  accuracy: 0.9552362155301075
# ######################################### 82
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.07
# accuracy: 0.9552362155301075
# %%%%%%% 0.039301701684261746
# len of big_cond 266699 len of trg weights 286772
# len of correcT_indices 273935 correct mals: 2951
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.5388 iter: 0 elapssed time: 125.32265043258667
# (553471, 580) (553471,) (553471,)
# ------------ 553471
# epoch: 1/1 ETA: 0:03 loss: 0.0031
# ######################################### 84
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.15
# accuracy: 0.9563381362197146
# %%%%%%% 0.039301701684261746
# len of big_cond 272264 len of trg weights 286772
# len of correcT_indices 274251 correct mals: 3192
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.4948 iter: 0 elapssed time: 130.22098398208618
# (559036, 580) (559036,) (559036,)
# ------------ 559036
# epoch: 1/1 ETA: 0:03 loss: 0.0031
# ######################################### 86
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.23
# accuracy: 0.957094834921122
# %%%%%%% 0.039301701684261746
# len of big_cond 277444 len of trg weights 286772
# len of correcT_indices 274468 correct mals: 3457
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.4389 iter: 0 elapssed time: 135.23776841163635
# (564216, 580) (564216,) (564216,)
# ------------ 564216
# epoch: 1/1 ETA: 0:02 loss: 0.0029
# ######################################### 88
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.31
# accuracy: 0.9573145216408855
# %%%%%%% 0.039301701684261746
# len of big_cond 282814 len of trg weights 286772
# len of correcT_indices 274531 correct mals: 3542
# >>>>>>>>>>>>>>>>>>>>>>>>>>3.6795 iter: 0 elapssed time: 140.0904185771942
# (569586, 580) (569586,) (569586,)
# ------------ 569586
# epoch: 1/1 ETA: 0:03 loss: 0.0030
# current accuracy on target domain:  accuracy: 0.9569448900171564
# accuracy: 0.9569448900171564
# -----___________________________________________===== MODE 2
# accuracy: 0.9569448900171564
# accuracy: 0.9569448900171564
# f1 score: 0.35067052327110176
# AUPRC: 0.2503279711712433
# accuracy: 0.9569448900171564
# 1.0539759397506714
# TPR: 0.03801732435033686
# 0.981971025466919
# TPR: 0.11870388193776067
# 0.029613830149173737
# TPR: 0.9499518768046198
# --------------------------------------------------------------------------------------------
# --------------------------------------------------------------------------------------------
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
#  iter: 1121/1121 ETA: 0:00 loss: 0.0839
#  iter: 1121/1121 ETA: 0:00 loss: 0.0354
#  iter: 1121/1121 ETA: 0:00 loss: 0.0270
#  iter: 1121/1121 ETA: 0:00 loss: 0.0215
#  iter: 1121/1121 ETA: 0:00 loss: 0.0183
#  iter: 1121/1121 ETA: 0:00 loss: 0.0167
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# accuracy: 0.7932523010152632
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
#  iter: 1121/1121 ETA: 0:00 loss: 0.0662
#  iter: 1121/1121 ETA: 0:00 loss: 0.0294
#  iter: 1121/1121 ETA: 0:00 loss: 0.0196
#  iter: 1121/1121 ETA: 0:00 loss: 0.0165
#  iter: 1121/1121 ETA: 0:00 loss: 0.0144
#  iter: 1121/1121 ETA: 0:00 loss: 0.0129
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1202da210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# accuracy: 0.8302173979665548
# err1:  0.2879937699944269 err2:  0.243344220804942
# f1_m1:  0.2717103925157616 f1_m2:  0.35067052327110176
# +++++++++++++++++++++++++++++++
# we_tu [('f1', 0.35067052327110176), ('auprc', 0.2503279711712433), ('acc', 0.9569448900171564)]
# +++++++++++++++++++++++++++++++

# %%
def model_selection(x_trg,yhat_target1,x_src,y_src,y_src_onehot):
    net1 = PacketModel()
    net1._set_inputs(tf.TensorSpec([None,timesteps*num_input]))

    base_lr = 0.0001
    optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
    grads = []
    for v in net1.trainable_variables:
        grads.append(np.zeros(v.shape))
    optimizer.apply_gradients(zip(grads,net1.trainable_variables))

    tsolver1 = Solver(optimizer,net1,base_lr)

    yhat_target1_onehot = np.zeros((len(yhat_target1),2),np.float32)
    yhat_target1_onehot[range(len(yhat_target1)),yhat_target1.astype(np.int32)] = 1.

    dhandler = DataHandler(x_trg,yhat_target1_onehot,None,batch_size=256,shuffle=True)


    nb_epochs = 6
    batch_size = 256
    total_batch = len(x_trg)//batch_size
    if len(x_trg) % batch_size!=0:
        total_batch+=1

    for i in range(nb_epochs):
        pos_inds = yhat_target1==1
        x_src_pos = x_trg[pos_inds]
        y_src_pos = yhat_target1_onehot[pos_inds]
        x_src_neg = x_trg[~pos_inds]
        y_src_neg = yhat_target1_onehot[~pos_inds]
        p = np.random.permutation(len(x_src_neg))
        x_src_neg = x_src_neg[p]
        y_src_neg = y_src_neg[p]
        pos_len = len(x_src_pos)

        src_dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
                                           ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

        train_model2(total_batch,src_dhandler,tsolver1)

#         for i in range(5):
#             train_model2(100,dhandler,tsolver1)
    return net1

#     _,logits_train_1 = test(x_src,y_src,net1,ret=True)
#     err1 = np.sum(np.abs(logits_train_1 - y_src_onehot)**2,axis=1)
#     err1 = np.mean(err1)
#     return err1

# %%
def model_selection_v2(x_trg,logits_hat,yhat,x_src,y_src,y_src_onehot):
    net1 = PacketModel()
    net1._set_inputs(tf.TensorSpec([None,timesteps*num_input]))

    base_lr = 0.0001
    optimizer = tf.keras.optimizers.Adam(learning_rate=base_lr)
    grads = []
    for v in net1.trainable_variables:
        grads.append(np.zeros(v.shape))
    optimizer.apply_gradients(zip(grads,net1.trainable_variables))

    tsolver1 = Solver(optimizer,net1,base_lr)

#     yhat_target1_onehot = np.zeros((len(yhat_target1),2),np.float32)
#     yhat_target1_onehot[range(len(yhat_target1)),yhat_target1.astype(np.int32)] = 1.

    dhandler = DataHandler(x_trg,logits_hat,None,batch_size=256,shuffle=True)


    nb_epochs = 6
    batch_size = 256
    total_batch = len(x_trg)//batch_size
    if len(x_trg) % batch_size!=0:
        total_batch+=1

    for i in range(nb_epochs):
        pos_inds = yhat==1
        x_src_pos = x_trg[pos_inds]
        y_src_pos = logits_hat[pos_inds]
        x_src_neg = x_trg[~pos_inds]
        y_src_neg = logits_hat[~pos_inds]
        p = np.random.permutation(len(x_src_neg))
        x_src_neg = x_src_neg[p]
        y_src_neg = y_src_neg[p]
        pos_len = len(x_src_pos)

        dhandler = DataHandler(np.concatenate((x_src_pos,x_src_neg[:pos_len]))
                                           ,np.concatenate((y_src_pos,y_src_neg[:pos_len])),None,batch_size=256,shuffle=True)

        train_model2(total_batch,dhandler,tsolver1)

#         for i in range(5):
#             train_model2(100,dhandler,tsolver1)
    return net1

#     _,logits_train_1 = test(x_src,y_src,net1,ret=True)
#     err1 = np.sum(np.abs(logits_train_1 - y_src_onehot)**2,axis=1)
#     err1 = np.mean(err1)
#     return err1

# %%
# err2 = model_selection(x_trg,yhat_target2,x_src,y_src,y_src_onehot)
# err1 = model_selection(x_trg,yhat_target1,x_src,y_src,y_src_onehot)
# print('err1: ',err1, 'err2: ',err2)
# print('f1_m1: ',f1_m1, 'f1_m2: ',f1_m2)

# %%
x_trg.shape,logits_target1.shape,logits_target2.shape
# Out:
# ((342621, 580), (342621, 2), (342621, 2))

# %%
logits_target1 = logits_target1.astype(np.float32)
logits_target2 = logits_target2.astype(np.float32)

# %%
# net1 = model_selection(x_trg,yhat_target1,x_src,y_src,y_src_onehot)
# net2 = model_selection(x_trg,yhat_target2,x_src,y_src,y_src_onehot)

net2 = model_selection_v2(x_trg,logits_target2,yhat_target2,x_src,y_src,y_src_onehot)
net1 = model_selection_v2(x_trg,logits_target1,yhat_target1,x_src,y_src,y_src_onehot)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
#  iter: 1339/1339 ETA: 0:00 loss: 0.0314
#  iter: 1339/1339 ETA: 0:00 loss: 0.0101
#  iter: 1339/1339 ETA: 0:00 loss: 0.0072
#  iter: 1339/1339 ETA: 0:00 loss: 0.0056
#  iter: 1339/1339 ETA: 0:00 loss: 0.0046
#  iter: 1339/1339 ETA: 0:00 loss: 0.0039
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
#  iter: 1339/1339 ETA: 0:00 loss: 0.0267
#  iter: 1339/1339 ETA: 0:00 loss: 0.0076
#  iter: 1339/1339 ETA: 0:00 loss: 0.0042
#  iter: 1339/1339 ETA: 0:00 loss: 0.0026
#  iter: 1339/1339 ETA: 0:00 loss: 0.0020
#  iter: 1339/1339 ETA: 0:00 loss: 0.0015

# %%
_ = calc_scores(x_src,y_src,net1,draw=False)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1cd790>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# accuracy: 0.9854239604982356
# accuracy: 0.9854239604982356
# f1 score: 0.536482590374806
# AUPRC: 0.8266618602978608

# %%
_ = calc_scores(x_src,y_src,net2,draw=False)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7fd1ea1c3b90>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# accuracy: 0.9782667066519743
# accuracy: 0.9782667066519743
# f1 score: 0.022889394058164144
# AUPRC: 0.658245866078367

# %%
_,logits_train_1 = test(x_src,y_src,net1,ret=True)
err1 = np.sum(np.abs(logits_train_1 - y_src_onehot)**2,axis=1)
err1 = np.mean(err1)

_,logits_train_2 = test(x_src,y_src,net2,ret=True)
err2 = np.sum(np.abs(logits_train_2 - y_src_onehot)**2,axis=1)
err2 = np.mean(err2)

print('err1',err1,'err2',err2)
# Out:
# accuracy: 0.9854239604982356
# accuracy: 0.9782667066519743
# err1 0.01976915089786419 err2 0.02774438800610258

# %%
np.sum(y_src==1)
# Out:
# 12468

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %%
#     _,logits_train_1 = test(x_src,y_src,net1,ret=True)
#     err1 = np.sum(np.abs(logits_train_1 - y_src_onehot)**2,axis=1)
#     err1 = np.mean(err1)

# %%
def print_res(ht=None):
    for src_day in days:
        for trg_day in days:
            if src_day == trg_day:
                continue
            name = src_day[:2]+'_'+trg_day[:2]
            if ht is None:
                print(name,end=' ')
            else:
                temp = ht[name][0][1] #f1 score
#                 temp = ht[name][4][1] #f1 score
                print(temp,end=' ')
    print()
print_res()
print_res(onlysrc_res)
print_res(pppl_res)
# Out:
# tu_we tu_th we_tu we_th th_tu th_we
# 0.0610450699568687 0.19323986523204 0.01647961358147464 0.1789714285714286 0.011385199240986715 0.013176276352552703
# 0.2731995179320949 0.707464813825049 0.27819971870604787 0.33883058470764615 0.7761930883159627 0.3229934135204666

# %%
a.reshape(1,-1)
# Out:
# array([[  1, 100]])

# %%
a = np.array((1,100))
a = a.reshape(1,-1)

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
tf.keras.layers.Softmax()(a)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-43-61336d065540> in <module>
# ----> 1 tf.keras.layers.Softmax()(a)
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     820           with base_layer_utils.autocast_context_manager(
#     821               self._compute_dtype):
# --> 822             outputs = self.call(cast_inputs, *args, **kwargs)
#     823           self._handle_activity_regularization(inputs, outputs)
#     824           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/advanced_activations.py in call(self, inputs)
#     258
#     259   def call(self, inputs):
# --> 260     return K.softmax(inputs, axis=self.axis)
#     261
#     262   def get_config(self):
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in softmax(x, axis)
#    4412       A tensor.
#    4413   """
# -> 4414   return nn.softmax(x, axis=axis)
#    4415
#    4416
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     505                 'in a future version' if date is None else ('after %s' % date),
#     506                 instructions)
# --> 507       return func(*args, **kwargs)
#     508
#     509     doc = _add_deprecated_arg_notice_to_docstring(
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in softmax(logits, axis, name, dim)
#    3009   if axis is None:
#    3010     axis = -1
# -> 3011   return _softmax(logits, gen_nn_ops.softmax, axis, name)
#    3012
#    3013
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in _softmax(logits, compute_op, dim, name)
#    2929
#    2930   if is_last_dim:
# -> 2931     return compute_op(logits, name=name)
#    2932
#    2933   dim_val = dim
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in softmax(logits, name)
#   10418         pass  # Add nodes to the TensorFlow graph.
#   10419     except _core._NotOkStatusException as e:
# > 10420       _ops.raise_from_not_ok_status(e, name)
#   10421   # Add nodes to the TensorFlow graph.
#   10422   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# NotFoundError: Could not find valid device for node.
# Node:{{node Softmax}}
# All kernels registered for op Softmax :
#   device='XLA_GPU'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_CPU'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_CPU_JIT'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_GPU_JIT'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_HALF]
#   device='GPU'; T in [DT_DOUBLE]
#   device='GPU'; T in [DT_FLOAT]
#   device='GPU'; T in [DT_HALF]
#  [Op:Softmax]

# %%
tf.nn.softmax(a)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-44-aa38aba58513> in <module>
# ----> 1 tf.nn.softmax(a)
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in softmax_v2(logits, axis, name)
#    3036   if axis is None:
#    3037     axis = -1
# -> 3038   return _softmax(logits, gen_nn_ops.softmax, axis, name)
#    3039
#    3040
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/nn_ops.py in _softmax(logits, compute_op, dim, name)
#    2929
#    2930   if is_last_dim:
# -> 2931     return compute_op(logits, name=name)
#    2932
#    2933   dim_val = dim
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_nn_ops.py in softmax(logits, name)
#   10418         pass  # Add nodes to the TensorFlow graph.
#   10419     except _core._NotOkStatusException as e:
# > 10420       _ops.raise_from_not_ok_status(e, name)
#   10421   # Add nodes to the TensorFlow graph.
#   10422   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# ~/anaconda3-gpu/envs/tf2/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# NotFoundError: Could not find valid device for node.
# Node:{{node Softmax}}
# All kernels registered for op Softmax :
#   device='XLA_GPU'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_CPU'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_CPU_JIT'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='XLA_GPU_JIT'; T in [DT_FLOAT, DT_DOUBLE, DT_BFLOAT16, DT_HALF]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_HALF]
#   device='GPU'; T in [DT_DOUBLE]
#   device='GPU'; T in [DT_FLOAT]
#   device='GPU'; T in [DT_HALF]
#  [Op:Softmax]

# %%
x_src.shape,x_trg.shape
# Out:
# ((462031, 580), (342621, 580))

# %%
with open('onlysrc_res2','wb') as f:
    pickle.dump(onlysrc_res,f)
    
with open('pppl_res2','wb') as f:
    pickle.dump(pppl_res,f)

# %%
DA(tsolver,trg_data,trg_gts,src_data,src_gts,trg_gt_class_percentage=trg_gt_class_percentage)
# Out:
# ######################################### 0
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.00
# accuracy: 0.9755450322904607
# len of big_cond 31546 len of trg weights 286772
# len of correcT_indices 279759 correct mals: 94
# >>>>>>>>>>>>>>>>>>>>>>>>>>1.1539 iter: 0 elapssed time: 1.274892807006836
# (318318, 580) (318318,) (318318,)
# ------------ 104732
# WARNING:tensorflow:AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7f6f5f89ee10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# WARNING: AutoGraph could not transform <bound method PacketModel.call of <__main__.PacketModel object at 0x7f6f5f89ee10>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: Bad argument number for Name: 3, expecting 4
# epoch: 1/1 ETA: 0:00 loss: 0.0108
# current accuracy on target domain:  accuracy: 0.9758274866444423
# ######################################### 2
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.06
# accuracy: 0.9758274866444423
# len of big_cond 37281 len of trg weights 286772
# len of correcT_indices 279840 correct mals: 57
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.8315 iter: 0 elapssed time: 4.9369611740112305
# (324053, 580) (324053,) (324053,)
# ------------ 103940
# epoch: 1/1 ETA: 0:00 loss: 0.0101
# ######################################### 4
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.10
# accuracy: 0.9755520064720405
# len of big_cond 43017 len of trg weights 286772
# len of correcT_indices 279761 correct mals: 74
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4928 iter: 0 elapssed time: 7.021706819534302
# (329789, 580) (329789,) (329789,)
# ------------ 104516
# epoch: 1/1 ETA: 0:00 loss: 0.0100
# ######################################### 6
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.13
# accuracy: 0.9754822646562425
# len of big_cond 48752 len of trg weights 286772
# len of correcT_indices 279741 correct mals: 98
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5866 iter: 0 elapssed time: 9.074798345565796
# (335524, 580) (335524,) (335524,)
# ------------ 104502
# epoch: 1/1 ETA: 0:00 loss: 0.0096
# ######################################### 8
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.17
# accuracy: 0.9751788877575217
# len of big_cond 54488 len of trg weights 286772
# len of correcT_indices 279654 correct mals: 99
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.7268 iter: 0 elapssed time: 11.562772035598755
# (341260, 580) (341260,) (341260,)
# ------------ 104990
# epoch: 1/1 ETA: 0:00 loss: 0.0096
# current accuracy on target domain:  accuracy: 0.9751196072140934
# ######################################### 10
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.23
# accuracy: 0.9751196072140934
# len of big_cond 60223 len of trg weights 286772
# len of correcT_indices 279637 correct mals: 208
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.6044 iter: 0 elapssed time: 15.22165036201477
# (346995, 580) (346995,) (346995,)
# ------------ 105162
# epoch: 1/1 ETA: 0:00 loss: 0.0093
# ######################################### 12
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.27
# accuracy: 0.9758518962799716
# len of big_cond 65959 len of trg weights 286772
# len of correcT_indices 279847 correct mals: 68
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4912 iter: 0 elapssed time: 17.57486915588379
# (352731, 580) (352731,) (352731,)
# ------------ 104474
# epoch: 1/1 ETA: 0:00 loss: 0.0088
# ######################################### 14
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.31
# accuracy: 0.9762215279037005
# len of big_cond 71694 len of trg weights 286772
# len of correcT_indices 279953 correct mals: 53
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.7783 iter: 0 elapssed time: 19.871166229248047
# (358466, 580) (358466,) (358466,)
# ------------ 104676
# epoch: 1/1 ETA: 0:00 loss: 0.0086
# ######################################### 16
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.35
# accuracy: 0.9756147741062586
# len of big_cond 77430 len of trg weights 286772
# len of correcT_indices 279779 correct mals: 80
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.6096 iter: 0 elapssed time: 22.23353338241577
# (364202, 580) (364202,) (364202,)
# ------------ 104004
# epoch: 1/1 ETA: 0:00 loss: 0.0086
# current accuracy on target domain:  accuracy: 0.9758623575523412
# ######################################### 18
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.41
# accuracy: 0.9758623575523412
# len of big_cond 83164 len of trg weights 286772
# len of correcT_indices 279850 correct mals: 168
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5171 iter: 0 elapssed time: 25.67962646484375
# (369936, 580) (369936,) (369936,)
# ------------ 105044
# epoch: 1/1 ETA: 0:00 loss: 0.0082
# ######################################### 20
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.44
# accuracy: 0.9760367120918361
# len of big_cond 88901 len of trg weights 286772
# len of correcT_indices 279900 correct mals: 107
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4713 iter: 0 elapssed time: 27.806515216827393
# (375673, 580) (375673,) (375673,)
# ------------ 104458
# epoch: 1/1 ETA: 0:00 loss: 0.0077
# ######################################### 22
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.48
# accuracy: 0.9755589806536203
# len of big_cond 94636 len of trg weights 286772
# len of correcT_indices 279763 correct mals: 136
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5347 iter: 0 elapssed time: 30.12477970123291
# (381408, 580) (381408,) (381408,)
# ------------ 105272
# epoch: 1/1 ETA: 0:00 loss: 0.0079
# ######################################### 24
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.52
# accuracy: 0.9759809186391977
# len of big_cond 100371 len of trg weights 286772
# len of correcT_indices 279884 correct mals: 102
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4742 iter: 0 elapssed time: 32.436447620391846
# (387143, 580) (387143,) (387143,)
# ------------ 104750
# epoch: 1/1 ETA: 0:00 loss: 0.0076
# current accuracy on target domain:  accuracy: 0.9758274866444423
# ######################################### 26
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.58
# accuracy: 0.9758274866444423
# len of big_cond 106106 len of trg weights 286772
# len of correcT_indices 279840 correct mals: 252
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5183 iter: 0 elapssed time: 35.72930550575256
# (392878, 580) (392878,) (392878,)
# ------------ 104864
# epoch: 1/1 ETA: 0:00 loss: 0.0076
# ######################################### 28
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.61
# accuracy: 0.9758170253720726
# len of big_cond 111842 len of trg weights 286772
# len of correcT_indices 279837 correct mals: 124
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4524 iter: 0 elapssed time: 37.93817663192749
# (398614, 580) (398614,) (398614,)
# ------------ 104994
# epoch: 1/1 ETA: 0:00 loss: 0.0073
# ######################################### 30
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.65
# accuracy: 0.9754508808391336
# len of big_cond 117578 len of trg weights 286772
# len of correcT_indices 279732 correct mals: 167
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4865 iter: 0 elapssed time: 40.16959834098816
# (404350, 580) (404350,) (404350,)
# ------------ 105296
# epoch: 1/1 ETA: 0:00 loss: 0.0070
# ######################################### 32
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.69
# accuracy: 0.9757926157365433
# len of big_cond 123313 len of trg weights 286772
# len of correcT_indices 279830 correct mals: 108
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5433 iter: 0 elapssed time: 42.355284452438354
# (410085, 580) (410085,) (410085,)
# ------------ 104550
# epoch: 1/1 ETA: 0:00 loss: 0.0070
# current accuracy on target domain:  accuracy: 0.9758553833707614
# ######################################### 34
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.74
# accuracy: 0.9758553833707614
# len of big_cond 129049 len of trg weights 286772
# len of correcT_indices 279848 correct mals: 284
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5014 iter: 0 elapssed time: 45.70130109786987
# (415821, 580) (415821,) (415821,)
# ------------ 106080
# epoch: 1/1 ETA: 0:00 loss: 0.0068
# ######################################### 36
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.78
# accuracy: 0.9763331148089772
# len of big_cond 134784 len of trg weights 286772
# len of correcT_indices 279985 correct mals: 104
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4563 iter: 0 elapssed time: 47.95612287521362
# (421556, 580) (421556,) (421556,)
# ------------ 105020
# epoch: 1/1 ETA: 0:00 loss: 0.0068
# ######################################### 38
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.82
# accuracy: 0.976071582999735
# len of big_cond 140519 len of trg weights 286772
# len of correcT_indices 279910 correct mals: 86
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4732 iter: 0 elapssed time: 50.20200538635254
# (427291, 580) (427291,) (427291,)
# ------------ 104438
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# ######################################### 40
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.85
# accuracy: 0.9759844057299876
# len of big_cond 146254 len of trg weights 286772
# len of correcT_indices 279885 correct mals: 89
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4396 iter: 0 elapssed time: 52.34931492805481
# (433026, 580) (433026,) (433026,)
# ------------ 104670
# epoch: 1/1 ETA: 0:00 loss: 0.0066
# current accuracy on target domain:  accuracy: 0.9763889082616155
# ######################################### 42
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.91
# accuracy: 0.9763889082616155
# len of big_cond 151990 len of trg weights 286772
# len of correcT_indices 280001 correct mals: 131
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4007 iter: 0 elapssed time: 55.686277627944946
# (438762, 580) (438762,) (438762,)
# ------------ 105710
# epoch: 1/1 ETA: 0:00 loss: 0.0062
# ######################################### 44
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.95
# accuracy: 0.9759634831852482
# len of big_cond 157726 len of trg weights 286772
# len of correcT_indices 279879 correct mals: 150
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4457 iter: 0 elapssed time: 57.950324058532715
# (444498, 580) (444498,) (444498,)
# ------------ 104692
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# ######################################### 46
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 0.98
# accuracy: 0.9759007155510301
# len of big_cond 163461 len of trg weights 286772
# len of correcT_indices 279861 correct mals: 348
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5286 iter: 0 elapssed time: 60.15945601463318
# (450233, 580) (450233,) (450233,)
# ------------ 106172
# epoch: 1/1 ETA: 0:00 loss: 0.0062
# ######################################### 48
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.02
# accuracy: 0.9765632628011103
# len of big_cond 169197 len of trg weights 286772
# len of correcT_indices 280051 correct mals: 467
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4728 iter: 0 elapssed time: 62.39932155609131
# (455969, 580) (455969,) (455969,)
# ------------ 105608
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# current accuracy on target domain:  accuracy: 0.978613672185569
# ######################################### 50
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.08
# accuracy: 0.978613672185569
# len of big_cond 174932 len of trg weights 286772
# len of correcT_indices 280639 correct mals: 1075
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4636 iter: 0 elapssed time: 65.8683135509491
# (461704, 580) (461704,) (461704,)
# ------------ 107198
# epoch: 1/1 ETA: 0:00 loss: 0.0066
# ######################################### 52
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.12
# accuracy: 0.9804164981239452
# len of big_cond 180667 len of trg weights 286772
# len of correcT_indices 281156 correct mals: 1605
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4423 iter: 0 elapssed time: 68.14093255996704
# (467439, 580) (467439,) (467439,)
# ------------ 107714
# epoch: 1/1 ETA: 0:00 loss: 0.0062
# ######################################### 54
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.15
# accuracy: 0.982731926408436
# len of big_cond 186402 len of trg weights 286772
# len of correcT_indices 281820 correct mals: 2394
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4667 iter: 0 elapssed time: 70.37174439430237
# (473174, 580) (473174,) (473174,)
# ------------ 108712
# epoch: 1/1 ETA: 0:00 loss: 0.0063
# ######################################### 56
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.19
# accuracy: 0.9837152860111866
# len of big_cond 192138 len of trg weights 286772
# len of correcT_indices 282102 correct mals: 2886
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4762 iter: 0 elapssed time: 72.71905303001404
# (478910, 580) (478910,) (478910,)
# ------------ 109598
# epoch: 1/1 ETA: 0:00 loss: 0.0066
# current accuracy on target domain:  accuracy: 0.9854588314061344
# ######################################### 58
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.25
# accuracy: 0.9854588314061344
# len of big_cond 197874 len of trg weights 286772
# len of correcT_indices 282602 correct mals: 3190
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.3907 iter: 0 elapssed time: 76.16516494750977
# (484646, 580) (484646,) (484646,)
# ------------ 110166
# epoch: 1/1 ETA: 0:00 loss: 0.0060
# ######################################### 60
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.29
# accuracy: 0.9858807693917119
# len of big_cond 203609 len of trg weights 286772
# len of correcT_indices 282723 correct mals: 3324
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.3860 iter: 0 elapssed time: 78.48339486122131
# (490381, 580) (490381,) (490381,)
# ------------ 490381
# epoch: 1/1 ETA: 0:02 loss: 0.0053
# ######################################### 62
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.35
# accuracy: 0.9861946075628025
# len of big_cond 209344 len of trg weights 286772
# len of correcT_indices 282813 correct mals: 3027
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2880 iter: 0 elapssed time: 82.09219884872437
# (496116, 580) (496116,) (496116,)
# ------------ 496116
# epoch: 1/1 ETA: 0:02 loss: 0.0048
# ######################################### 64
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.41
# accuracy: 0.9866967486365475
# len of big_cond 215080 len of trg weights 286772
# len of correcT_indices 282957 correct mals: 3145
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2413 iter: 0 elapssed time: 85.70040464401245
# (501852, 580) (501852,) (501852,)
# ------------ 501852
# epoch: 1/1 ETA: 0:02 loss: 0.0044
# current accuracy on target domain:  accuracy: 0.9863585008299276
# ######################################### 66
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.49
# accuracy: 0.9863585008299276
# len of big_cond 220815 len of trg weights 286772
# len of correcT_indices 282860 correct mals: 2918
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2445 iter: 0 elapssed time: 90.38586163520813
# (507587, 580) (507587,) (507587,)
# ------------ 507587
# epoch: 1/1 ETA: 0:02 loss: 0.0042
# ######################################### 68
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.55
# accuracy: 0.9871465833484441
# len of big_cond 226550 len of trg weights 286772
# len of correcT_indices 283086 correct mals: 3167
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2675 iter: 0 elapssed time: 94.07121205329895
# (513322, 580) (513322,) (513322,)
# ------------ 513322
# epoch: 1/1 ETA: 0:02 loss: 0.0039
# ######################################### 70
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.61
# accuracy: 0.987380218431367
# len of big_cond 232286 len of trg weights 286772
# len of correcT_indices 283153 correct mals: 3288
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2686 iter: 0 elapssed time: 97.71690154075623
# (519058, 580) (519058,) (519058,)
# ------------ 519058
# epoch: 1/1 ETA: 0:02 loss: 0.0038
# ######################################### 72
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.67
# accuracy: 0.9868501806313029
# len of big_cond 238021 len of trg weights 286772
# len of correcT_indices 283001 correct mals: 3076
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2605 iter: 0 elapssed time: 101.39702701568604
# (524793, 580) (524793,) (524793,)
# ------------ 524793
# epoch: 1/1 ETA: 0:02 loss: 0.0036
# current accuracy on target domain:  accuracy: 0.987718466237987
# ######################################### 74
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.75
# accuracy: 0.987718466237987
# len of big_cond 243757 len of trg weights 286772
# len of correcT_indices 283250 correct mals: 3306
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2388 iter: 0 elapssed time: 106.2629656791687
# (530529, 580) (530529,) (530529,)
# ------------ 530529
# epoch: 1/1 ETA: 0:02 loss: 0.0035
# ######################################### 76
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.81
# accuracy: 0.9877289275103567
# len of big_cond 249492 len of trg weights 286772
# len of correcT_indices 283253 correct mals: 3293
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2693 iter: 0 elapssed time: 110.08085751533508
# (536264, 580) (536264,) (536264,)
# ------------ 536264
# epoch: 1/1 ETA: 0:02 loss: 0.0033
# ######################################### 78
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.88
# accuracy: 0.988049739863027
# len of big_cond 255228 len of trg weights 286772
# len of correcT_indices 283345 correct mals: 3431
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2555 iter: 0 elapssed time: 113.83791017532349
# (542000, 580) (542000,) (542000,)
# ------------ 542000
# epoch: 1/1 ETA: 0:02 loss: 0.0032
# ######################################### 80
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 1.94
# accuracy: 0.9879555884116998
# len of big_cond 260963 len of trg weights 286772
# len of correcT_indices 283318 correct mals: 3376
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2564 iter: 0 elapssed time: 117.6785397529602
# (547735, 580) (547735,) (547735,)
# ------------ 547735
# epoch: 1/1 ETA: 0:02 loss: 0.0031
# current accuracy on target domain:  accuracy: 0.9884263456683359
# ######################################### 82
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.03
# accuracy: 0.9884263456683359
# len of big_cond 266699 len of trg weights 286772
# len of correcT_indices 283453 correct mals: 3525
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2572 iter: 0 elapssed time: 122.73825025558472
# (553471, 580) (553471,) (553471,)
# ------------ 553471
# epoch: 1/1 ETA: 0:02 loss: 0.0030
# ######################################### 84
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.09
# accuracy: 0.9892771958210704
# len of big_cond 272435 len of trg weights 286772
# len of correcT_indices 283697 correct mals: 3799
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.2760 iter: 0 elapssed time: 126.58316612243652
# (559207, 580) (559207,) (559207,)
# ------------ 559207
# epoch: 1/1 ETA: 0:02 loss: 0.0030
# ######################################### 86
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.16
# accuracy: 0.9889633576499798
# len of big_cond 278170 len of trg weights 286772
# len of correcT_indices 283607 correct mals: 3692
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.3297 iter: 0 elapssed time: 130.4908003807068
# (564942, 580) (564942,) (564942,)
# ------------ 564942
# epoch: 1/1 ETA: 0:02 loss: 0.0028
# ######################################### 88
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 0 Elapsed Time(m): 2.22
# accuracy: 0.989992049432999
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 283902 correct mals: 3991
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5012 iter: 0 elapssed time: 134.35774946212769
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0029
# current accuracy on target domain:  accuracy: 0.9904000390554168
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 1 Elapsed Time(m): 2.30
# accuracy: 0.9904000390554168
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284019 correct mals: 4124
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.5026 iter: 1 elapssed time: 139.42507886886597
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0028
# current accuracy on target domain:  accuracy: 0.9907905932238852
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 2 Elapsed Time(m): 2.39
# accuracy: 0.9907905932238852
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284131 correct mals: 4223
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4621 iter: 2 elapssed time: 144.46752524375916
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0028
# current accuracy on target domain:  accuracy: 0.9911950957555131
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 3 Elapsed Time(m): 2.47
# accuracy: 0.9911950957555131
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284247 correct mals: 4337
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4368 iter: 3 elapssed time: 149.57673907279968
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0027
# current accuracy on target domain:  accuracy: 0.9914357050200159
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 4 Elapsed Time(m): 2.56
# accuracy: 0.9914357050200159
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284316 correct mals: 4459
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4558 iter: 4 elapssed time: 154.56545972824097
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0027
# current accuracy on target domain:  accuracy: 0.99163446919504
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 5 Elapsed Time(m): 2.64
# accuracy: 0.99163446919504
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284373 correct mals: 4475
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4297 iter: 5 elapssed time: 159.6420373916626
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0026
# current accuracy on target domain:  accuracy: 0.9922063520845829
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 6 Elapsed Time(m): 2.73
# accuracy: 0.9922063520845829
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284537 correct mals: 4711
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4160 iter: 6 elapssed time: 164.64258122444153
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0026
# current accuracy on target domain:  accuracy: 0.9919448202753407
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 7 Elapsed Time(m): 2.81
# accuracy: 0.9919448202753407
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284462 correct mals: 4590
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4128 iter: 7 elapssed time: 169.7964186668396
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0025
# current accuracy on target domain:  accuracy: 0.9924504484398756
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 8 Elapsed Time(m): 2.90
# accuracy: 0.9924504484398756
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284607 correct mals: 4738
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.3850 iter: 8 elapssed time: 174.89698576927185
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:02 loss: 0.0025
# current accuracy on target domain:  accuracy: 0.9922726068095908
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^ epoch: 9 Elapsed Time(m): 2.98
# accuracy: 0.9922726068095908
# len of big_cond 283905 len of trg weights 286772
# len of correcT_indices 284556 correct mals: 4686
# >>>>>>>>>>>>>>>>>>>>>>>>>>0.4089 iter: 9 elapssed time: 179.99253344535828
# (570677, 580) (570677,) (570677,)
# ------------ 570677
# epoch: 1/1 ETA: 0:03 loss: 0.0024
# current accuracy on target domain:  accuracy: 0.99263875134253

# %%
f1,auprc,acc = calc_scores(x_trg,y_trg,net,draw=False)
# Out:
# accuracy: 0.99330827277419
# accuracy: 0.99330827277419
# f1 score: 0.8377715783244568
# AUPRC: 0.8846457023598123

# %%
y_pred_trg,scores_trg = test(x_trg,y_trg,net,ret=True)
for fpr in [0.001,0.01,0.1]:
    scores = scores_trg[:,1]
#     fpr = 0.01
    benign_scores = scores[y_trg==0]
    benign_scores_sorted = np.sort(benign_scores)
    thr_ind = int(np.ceil(len(benign_scores_sorted)*fpr))
    thr = benign_scores_sorted[-thr_ind]
    print (thr)
    mal_scores = scores[y_trg==1]
    tpr = np.sum(mal_scores>thr)/len(mal_scores)
    print('TPR:',tpr)
    pppl_res[name].append((fpr,tpr))
# Out:
# accuracy: 0.99330827277419
# 0.8530188798904419
# TPR: 0.47112608277189605
# 0.13573472201824188
# TPR: 0.9619826756496631
# 0.01047850213944912
# TPR: 0.9955085017645172
